# %% [markdown]
# # Crawling Web PTA Trunojoyo

# %%
# !pip install requests
# !pip install beautifulsoup4
import requests
from bs4 import BeautifulSoup
import pandas as pd
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.8.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)

# %% [markdown]
# ## Fakultas Hukum

# %% [markdown]
# ### A.Prodi Ilmu Hukum

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def ptaa():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 285):
        print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/1/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("IlmuHukum.csv", index=False)

    return df

# %%
ptaa()
# Out:
# 📄 Memproses halaman ke-1
# 📄 Memproses halaman ke-2
# 📄 Memproses halaman ke-3
# 📄 Memproses halaman ke-4
# 📄 Memproses halaman ke-5
# 📄 Memproses halaman ke-6
# 📄 Memproses halaman ke-7
# 📄 Memproses halaman ke-8
# 📄 Memproses halaman ke-9
# 📄 Memproses halaman ke-10
# 📄 Memproses halaman ke-11
# 📄 Memproses halaman ke-12
# 📄 Memproses halaman ke-13
# 📄 Memproses halaman ke-14
# 📄 Memproses halaman ke-15
# 📄 Memproses halaman ke-16
# 📄 Memproses halaman ke-17
# 📄 Memproses halaman ke-18
# 📄 Memproses halaman ke-19
# 📄 Memproses halaman ke-20
# 📄 Memproses halaman ke-21
# 📄 Memproses halaman ke-22
# 📄 Memproses halaman ke-23
# 📄 Memproses halaman ke-24
# 📄 Memproses halaman ke-25
# 📄 Memproses halaman ke-26
# 📄 Memproses halaman ke-27
# 📄 Memproses halaman ke-28
# 📄 Memproses halaman ke-29
# 📄 Memproses halaman ke-30
# 📄 Memproses halaman ke-31
# 📄 Memproses halaman ke-32
# 📄 Memproses halaman ke-33
# 📄 Memproses halaman ke-34
# 📄 Memproses halaman ke-35
# 📄 Memproses halaman ke-36
# 📄 Memproses halaman ke-37
# 📄 Memproses halaman ke-38
# 📄 Memproses halaman ke-39
# 📄 Memproses halaman ke-40
# 📄 Memproses halaman ke-41
# 📄 Memproses halaman ke-42
# 📄 Memproses halaman ke-43
# 📄 Memproses halaman ke-44
# 📄 Memproses halaman ke-45
# 📄 Memproses halaman ke-46
# 📄 Memproses halaman ke-47
# 📄 Memproses halaman ke-48
# 📄 Memproses halaman ke-49
# 📄 Memproses halaman ke-50
# 📄 Memproses halaman ke-51
# 📄 Memproses halaman ke-52
# 📄 Memproses halaman ke-53
# 📄 Memproses halaman ke-54
# 📄 Memproses halaman ke-55
# 📄 Memproses halaman ke-56
# 📄 Memproses halaman ke-57
# 📄 Memproses halaman ke-58
# 📄 Memproses halaman ke-59
# 📄 Memproses halaman ke-60
# 📄 Memproses halaman ke-61
# 📄 Memproses halaman ke-62
# 📄 Memproses halaman ke-63
# 📄 Memproses halaman ke-64
# 📄 Memproses halaman ke-65
# 📄 Memproses halaman ke-66
# 📄 Memproses halaman ke-67
# 📄 Memproses halaman ke-68
# 📄 Memproses halaman ke-69
# 📄 Memproses halaman ke-70
# 📄 Memproses halaman ke-71
# 📄 Memproses halaman ke-72
# 📄 Memproses halaman ke-73
# 📄 Memproses halaman ke-74
# 📄 Memproses halaman ke-75
# 📄 Memproses halaman ke-76
# 📄 Memproses halaman ke-77
# 📄 Memproses halaman ke-78
# 📄 Memproses halaman ke-79
# 📄 Memproses halaman ke-80
# 📄 Memproses halaman ke-81
# 📄 Memproses halaman ke-82
# 📄 Memproses halaman ke-83
# 📄 Memproses halaman ke-84
# 📄 Memproses halaman ke-85
# 📄 Memproses halaman ke-86
# 📄 Memproses halaman ke-87
# 📄 Memproses halaman ke-88
# 📄 Memproses halaman ke-89
# 📄 Memproses halaman ke-90
# 📄 Memproses halaman ke-91
# 📄 Memproses halaman ke-92
# 📄 Memproses halaman ke-93
# 📄 Memproses halaman ke-94
# 📄 Memproses halaman ke-95
# 📄 Memproses halaman ke-96
# 📄 Memproses halaman ke-97
# 📄 Memproses halaman ke-98
# 📄 Memproses halaman ke-99
# 📄 Memproses halaman ke-100
# 📄 Memproses halaman ke-101
# 📄 Memproses halaman ke-102
# 📄 Memproses halaman ke-103
# 📄 Memproses halaman ke-104
# 📄 Memproses halaman ke-105
# 📄 Memproses halaman ke-106
# 📄 Memproses halaman ke-107
# 📄 Memproses halaman ke-108
# 📄 Memproses halaman ke-109
# 📄 Memproses halaman ke-110
# 📄 Memproses halaman ke-111
# 📄 Memproses halaman ke-112
# 📄 Memproses halaman ke-113
# 📄 Memproses halaman ke-114
# 📄 Memproses halaman ke-115
# 📄 Memproses halaman ke-116
# 📄 Memproses halaman ke-117
# 📄 Memproses halaman ke-118
# 📄 Memproses halaman ke-119
# 📄 Memproses halaman ke-120
# 📄 Memproses halaman ke-121
# 📄 Memproses halaman ke-122
# 📄 Memproses halaman ke-123
# 📄 Memproses halaman ke-124
# 📄 Memproses halaman ke-125
# 📄 Memproses halaman ke-126
# 📄 Memproses halaman ke-127
# 📄 Memproses halaman ke-128
# 📄 Memproses halaman ke-129
# 📄 Memproses halaman ke-130
# 📄 Memproses halaman ke-131
# 📄 Memproses halaman ke-132
# 📄 Memproses halaman ke-133
# 📄 Memproses halaman ke-134
# 📄 Memproses halaman ke-135
# 📄 Memproses halaman ke-136
# 📄 Memproses halaman ke-137
# 📄 Memproses halaman ke-138
# 📄 Memproses halaman ke-139
# 📄 Memproses halaman ke-140
# 📄 Memproses halaman ke-141
# 📄 Memproses halaman ke-142
# 📄 Memproses halaman ke-143
# 📄 Memproses halaman ke-144
# 📄 Memproses halaman ke-145
# 📄 Memproses halaman ke-146
# 📄 Memproses halaman ke-147
# 📄 Memproses halaman ke-148
# 📄 Memproses halaman ke-149
# 📄 Memproses halaman ke-150
# 📄 Memproses halaman ke-151
# 📄 Memproses halaman ke-152
# 📄 Memproses halaman ke-153
# 📄 Memproses halaman ke-154
# 📄 Memproses halaman ke-155
# 📄 Memproses halaman ke-156
# 📄 Memproses halaman ke-157
# 📄 Memproses halaman ke-158
# 📄 Memproses halaman ke-159
# 📄 Memproses halaman ke-160
# 📄 Memproses halaman ke-161
# 📄 Memproses halaman ke-162
# 📄 Memproses halaman ke-163
# 📄 Memproses halaman ke-164
# 📄 Memproses halaman ke-165
# 📄 Memproses halaman ke-166
# 📄 Memproses halaman ke-167
# 📄 Memproses halaman ke-168
# 📄 Memproses halaman ke-169
# 📄 Memproses halaman ke-170
# 📄 Memproses halaman ke-171
# 📄 Memproses halaman ke-172
# 📄 Memproses halaman ke-173
# 📄 Memproses halaman ke-174
# 📄 Memproses halaman ke-175
# 📄 Memproses halaman ke-176
# 📄 Memproses halaman ke-177
# 📄 Memproses halaman ke-178
# 📄 Memproses halaman ke-179
# 📄 Memproses halaman ke-180
# 📄 Memproses halaman ke-181
# 📄 Memproses halaman ke-182
# 📄 Memproses halaman ke-183
# 📄 Memproses halaman ke-184
# 📄 Memproses halaman ke-185
# 📄 Memproses halaman ke-186
# 📄 Memproses halaman ke-187
# 📄 Memproses halaman ke-188
# 📄 Memproses halaman ke-189
# 📄 Memproses halaman ke-190
# 📄 Memproses halaman ke-191
# 📄 Memproses halaman ke-192
# 📄 Memproses halaman ke-193
# 📄 Memproses halaman ke-194
# 📄 Memproses halaman ke-195
# 📄 Memproses halaman ke-196
# 📄 Memproses halaman ke-197
# 📄 Memproses halaman ke-198
# 📄 Memproses halaman ke-199
# 📄 Memproses halaman ke-200
# 📄 Memproses halaman ke-201
# 📄 Memproses halaman ke-202
# 📄 Memproses halaman ke-203
# 📄 Memproses halaman ke-204
# 📄 Memproses halaman ke-205
# 📄 Memproses halaman ke-206
# 📄 Memproses halaman ke-207
# 📄 Memproses halaman ke-208
# 📄 Memproses halaman ke-209
# 📄 Memproses halaman ke-210
# 📄 Memproses halaman ke-211
# 📄 Memproses halaman ke-212
# 📄 Memproses halaman ke-213
# 📄 Memproses halaman ke-214
# 📄 Memproses halaman ke-215
# 📄 Memproses halaman ke-216
# 📄 Memproses halaman ke-217
# 📄 Memproses halaman ke-218
# 📄 Memproses halaman ke-219
# 📄 Memproses halaman ke-220
# 📄 Memproses halaman ke-221
# 📄 Memproses halaman ke-222
# 📄 Memproses halaman ke-223
# 📄 Memproses halaman ke-224
# 📄 Memproses halaman ke-225
# 📄 Memproses halaman ke-226
# 📄 Memproses halaman ke-227
# 📄 Memproses halaman ke-228
# 📄 Memproses halaman ke-229
# 📄 Memproses halaman ke-230
# 📄 Memproses halaman ke-231
# 📄 Memproses halaman ke-232
# 📄 Memproses halaman ke-233
# 📄 Memproses halaman ke-234
# 📄 Memproses halaman ke-235
# 📄 Memproses halaman ke-236
# 📄 Memproses halaman ke-237
# 📄 Memproses halaman ke-238
# 📄 Memproses halaman ke-239
# 📄 Memproses halaman ke-240
# 📄 Memproses halaman ke-241
# 📄 Memproses halaman ke-242
# 📄 Memproses halaman ke-243
# 📄 Memproses halaman ke-244
# 📄 Memproses halaman ke-245
# 📄 Memproses halaman ke-246
# 📄 Memproses halaman ke-247
# 📄 Memproses halaman ke-248
# 📄 Memproses halaman ke-249
# 📄 Memproses halaman ke-250
# 📄 Memproses halaman ke-251
# 📄 Memproses halaman ke-252
# 📄 Memproses halaman ke-253
# 📄 Memproses halaman ke-254
# 📄 Memproses halaman ke-255
# 📄 Memproses halaman ke-256
# 📄 Memproses halaman ke-257
# 📄 Memproses halaman ke-258
# 📄 Memproses halaman ke-259
# 📄 Memproses halaman ke-260
# 📄 Memproses halaman ke-261
# 📄 Memproses halaman ke-262
# 📄 Memproses halaman ke-263
# 📄 Memproses halaman ke-264
# 📄 Memproses halaman ke-265
# 📄 Memproses halaman ke-266
# 📄 Memproses halaman ke-267
# 📄 Memproses halaman ke-268
# 📄 Memproses halaman ke-269
# 📄 Memproses halaman ke-270
# 📄 Memproses halaman ke-271
# 📄 Memproses halaman ke-272
# 📄 Memproses halaman ke-273
# 📄 Memproses halaman ke-274
# 📄 Memproses halaman ke-275
# 📄 Memproses halaman ke-276
# 📄 Memproses halaman ke-277
# 📄 Memproses halaman ke-278
# 📄 Memproses halaman ke-279
# 📄 Memproses halaman ke-280
# 📄 Memproses halaman ke-281
# 📄 Memproses halaman ke-282
# 📄 Memproses halaman ke-283
# 📄 Memproses halaman ke-284
#                                penulis  \
# 0                  Dyah Ayu Citra Seza
# 1                     Maulina Nurlaily
# 2                  Moh. Samsul Hidayat
# 3     TOMMY ADITYA PARLINDUNGAN MARBUN
# 4                   RICA YENA IMADHORA
# ...                                ...
# 1412                        DEDY DORES
# 1413                      Eko Supriadi
# 1414              Muslimatul Maghfirah
# 1415                MOH WASIL SYAHRONI
# 1416                      Moch. Steven
#
#                                                   judul  \
# 0     Implementasi Fungsi Legislasi Dewan Perwakilan...
# 1     Pertanggungjawaban Pidana Direksi BUMN (Perser...
# 2     Analisis Terhadap Kekosongan Hukum dalam Penga...
# 3     PERLINDUNGAN HUKUM BAGI KONSUMEN ATAS PRODUK E...
# 4     TELAAH  KRITIS TENTANG ALASAN HUKUM YANG DIGUN...
# ...                                                 ...
# 1412  PENGKUALIFIKASIAN CHEATER SEBAGAI TINDAK PIDAN...
# 1413  KUALIFIKASI TINDAK PIDANA ATAS PERBUATAN PELAK...
# 1414  KEDUDUKAN HUKUM PEKERJA OUTSOURCING DI DINAS P...
# 1415  STAGNANSI HUBUNGAN KELEMBAGAAN DAN KEWENANGAN ...
# 1416  PERUMUSAN SANKSI PIDANA BAGI MASYARAKAT SEKITA...
#
#                              pembimbing_pertama  \
# 0               Yudi Widagdo Harimurti, SH., MH
# 1                       Tolib Effendi, SH., MH.
# 2                       Tolib Effendi, SH., MH.
# 3                     DR. DJULAEKA, S.H., M.HUM
# 4                    Dr. DENI SBY, S. H., M. S.
# ...                                         ...
# 1412                Aris Hardinanto, S.H., M.H.
# 1413                Dr. Erma Rusdiana, S.H.,M.H
# 1414               Mishbahul Munir, S.H., M.Hum
# 1415  Dr. DENI SETYA BAGUS YUHERAWAN, S.H., M.S
# 1416              Dr. Wartiningsih, S.H., M.Hum
#
#                       pembimbing_kedua  \
# 0                       Safi', SH., MH
# 1         Dr. Eni Suastuti, SH., Mhum.
# 2              Agus Ramdlany, SH., MH.
# 3     DR.USWATUN HASANAH, S.H., M. HUM
# 4        SAIFUL ABDULLAH, S. H., M. H.
# ...                                ...
# 1412
# 1413
# 1414
# 1415
# 1416
#
#                                            abstrak_indo  \
# 0     ABSTRAK\r\n\r\n       Implementasi Fungsi Legi...
# 1     Badan Usaha Milik Negara (BUMN) adalah Badan u...
# 2     Kasus narkoba tidak henti-hentinya terdengar d...
# 3     Produk elektronik adalah suatu benda bergerak ...
# 4
# ...                                                 ...
# 1412  Abstrak\n Perbuatan cheater dalam melakukan ch...
# 1413  Peminjaman dana sistem online dilakukan oleh m...
# 1414  Abstrak\nTenaga kerja merupakan setiap orang y...
# 1415  Skripsi ini bertujuan untuk menganalisis penti...
# 1416  ABSTRAK\nAkhir-akhir ini semakin maraknya penc...
#
#                                         abstrak_inggris
# 0     ABSTRACT\r\n       Implementation of Legislati...
# 1     State Owned Enterprises (SOEs) are business en...
# 2     Drug cases endlessly heard on television, radi...
# 3     Electronic products is an object moves through...
# 4
# ...                                                 ...
# 1412  Abstract\n The way of cheater did a cheat in o...
# 1413  The loan funds by online system are carried ou...
# 1414  Abstract\nLabors are those who can work to pro...
# 1415  This thesis aims to analyze the stagnation of ...
# 1416  ABSTRACK\nLately, there has been more and more...
#
# [1417 rows x 6 columns]

# %% [markdown]
# ### B.Prodi Magister Ilmu Hukum

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def mhukum():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 15):
        print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/24/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("mhukum.csv", index=False)
A
    return df

# %%
mhukum()
# Out:
# 📄 Memproses halaman ke-1
# 📄 Memproses halaman ke-2
# 📄 Memproses halaman ke-3
# 📄 Memproses halaman ke-4
# 📄 Memproses halaman ke-5
# 📄 Memproses halaman ke-6
# 📄 Memproses halaman ke-7
# 📄 Memproses halaman ke-8
# 📄 Memproses halaman ke-9
# 📄 Memproses halaman ke-10
# 📄 Memproses halaman ke-11
# 📄 Memproses halaman ke-12
# 📄 Memproses halaman ke-13
# 📄 Memproses halaman ke-14
#                       penulis  \
# 0             MOCHAMAD SAICHU
# 1        nanang hariansah, SH
# 2                SOELISTIJONO
# 3   DIAH TRI SETIANINGSIH,S.H
# 4                     WAHYUDI
# ..                        ...
# 63                     HAMIDI
# 64            Ach. Eli Fadlal
# 65         Iwan Santoso, S.H.
# 66               BUNTORO, S.H
# 67            Rachmad Hidayat
#
#                                                 judul  \
# 0   PERTANGGUNG JAWABAN HUKUM PEJABAT PEMBUAT KOMI...
# 1   KARAKTERISTIK KONTRAK PEMERINTAH PENGADAAN BAR...
# 2   PEMBERHENTIAN TIDAK DENGAN HORMAT BAGI ANGGOTA...
# 3   KONSEP ANAK YANG BERKONFLIK DENGAN HUKUM DALAM...
# 4   PENATAGUNAAN TANAH DALAM UPAYA OPTIMALISASI PE...
# ..                                                ...
# 63  KEWENANGAN KANTOR PERTANAHAN DALAM MENYELESAIK...
# 64  MENYETUBUHI MAYAT DALAM PERSPEKTIF HUKUM PIDAN...
# 65  ANALISA HUKUM SELEKSI PENERIMAAN APARATUR\nSIP...
# 66  Penyelesaian Tindak Pidana yang Dilatarbelakan...
# 67  ASPEK HUKUM KEWENANGAN PENGEMBANGAN KAWASAN IN...
#
#                           pembimbing_pertama                 pembimbing_kedua  \
# 0             Dr. Nunuk Nuswardani S.H., M.H  Dr. Deni SB Yuherawan S.H., Msi
# 1                   Dr. DJULAEKA, SH., M.Hum            Dr. MURNI, SH., M.Hum
# 2        Dr. MUFARRIJUL IKHWAN, S.H., M.Hum.  Dr. NUNUK NUSWARDANI, S.H., M.H
# 3              Dr. Deni SB Yuherawan,S.H.,MS     Dr. Wartiningsih, S.H., Mhum
# 4            Dr. Mufarrijul Ikhwan, SH.,MHum     Dr. Indien Winarwati, SH.,MH
# ..                                       ...                              ...
# 63           Dr. Indien Winarwati, S.H., M.H        Dr. Djulaeka, S.H., M.Hum
# 64            Dr. Erma Rusdiana., S.H., M.H.   Dr. Eny Suastuti., SH., M. Hum
# 65   Dr. Yudi Widagdo Harimurti., S.H., M.H.   Dr. Wartiningsih., SH., M. Hum
# 66  Dr. Deny Setya Bagus Yuherawan, S.H.,M.S    Dr. Syamsul Fatoni, S.H.,M.H.
# 67                          Dr. Safi, SH, MH          Dr. Nuruz Zaman, SH, MH
#
#                                          abstrak_indo  \
# 0   Korupsi  tergolong ke dalam kejahatan  yang  l...
# 1   Kontrak pengadaan barang/jasa pemerintah adala...
# 2   ABSTRAKSI\r\n\r\nPEMBERHENTIAN TIDAK DENGAN HO...
# 3   Sistem Peradilan Pidana Anak saat ini telah me...
# 4   Keberadaan tanah merupakan hal yang sangat pen...
# ..                                                ...
# 63  Permasalahan sengketa pertanahan merupakan mas...
# 64  ABSTRAK\n\nMenyetubuhi dapat didefinisikan seb...
# 65  Aparatur Sipil Negara adalah profesi bagi pega...
# 66  Pasal 28E ayat (1) Undang-Undang Dasar Negara ...
# 67  Research conducted in this thesis is normative...
#
#                                       abstrak_inggris
# 0   Korupsi  tergolong ke dalam kejahatan  yang  l...
# 1   Government goods/service supplying contractt i...
# 2   ABSTRACT\r\n\r\nDISMISSAL NOT WITH RESPECT TO ...
# 3   Juvenile Criminal Justice System today has und...
# 4   The existence of the soil is very important fo...
# ..                                                ...
# 63  The issue of land disputes is a complex issue ...
# 64  ABSTRACT\n\nIntercourse can be defined as sexu...
# 65  The State Civil Apparatus is a profession for ...
# 66  Article 28E paragraph (1) of the Constitution ...
# 67  Research conducted in this thesis is normative...
#
# [68 rows x 6 columns]

# %% [markdown]
# ## Fakultas Pertanian

# %% [markdown]
# ### A.Prodi Teknologi Industri Pertanian

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def tip():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 115):
        print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/2/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("TIP.csv", index=False)

    return df

# %%
tip()
# Out:
# 📄 Memproses halaman ke-1
# 📄 Memproses halaman ke-2
# 📄 Memproses halaman ke-3
# 📄 Memproses halaman ke-4
# 📄 Memproses halaman ke-5
# 📄 Memproses halaman ke-6
# 📄 Memproses halaman ke-7
# 📄 Memproses halaman ke-8
# 📄 Memproses halaman ke-9
# 📄 Memproses halaman ke-10
# 📄 Memproses halaman ke-11
# 📄 Memproses halaman ke-12
# 📄 Memproses halaman ke-13
# 📄 Memproses halaman ke-14
# 📄 Memproses halaman ke-15
# 📄 Memproses halaman ke-16
# 📄 Memproses halaman ke-17
# 📄 Memproses halaman ke-18
# 📄 Memproses halaman ke-19
# 📄 Memproses halaman ke-20
# 📄 Memproses halaman ke-21
# 📄 Memproses halaman ke-22
# 📄 Memproses halaman ke-23
# 📄 Memproses halaman ke-24
# 📄 Memproses halaman ke-25
# 📄 Memproses halaman ke-26
# 📄 Memproses halaman ke-27
# 📄 Memproses halaman ke-28
# 📄 Memproses halaman ke-29
# 📄 Memproses halaman ke-30
# 📄 Memproses halaman ke-31
# 📄 Memproses halaman ke-32
# 📄 Memproses halaman ke-33
# 📄 Memproses halaman ke-34
# 📄 Memproses halaman ke-35
# 📄 Memproses halaman ke-36
# 📄 Memproses halaman ke-37
# 📄 Memproses halaman ke-38
# 📄 Memproses halaman ke-39
# 📄 Memproses halaman ke-40
# 📄 Memproses halaman ke-41
# 📄 Memproses halaman ke-42
# 📄 Memproses halaman ke-43
# 📄 Memproses halaman ke-44
# 📄 Memproses halaman ke-45
# 📄 Memproses halaman ke-46
# 📄 Memproses halaman ke-47
# 📄 Memproses halaman ke-48
# 📄 Memproses halaman ke-49
# 📄 Memproses halaman ke-50
# 📄 Memproses halaman ke-51
# 📄 Memproses halaman ke-52
# 📄 Memproses halaman ke-53
# 📄 Memproses halaman ke-54
# 📄 Memproses halaman ke-55
# 📄 Memproses halaman ke-56
# 📄 Memproses halaman ke-57
# 📄 Memproses halaman ke-58
# 📄 Memproses halaman ke-59
# 📄 Memproses halaman ke-60
# 📄 Memproses halaman ke-61
# 📄 Memproses halaman ke-62
# 📄 Memproses halaman ke-63
# 📄 Memproses halaman ke-64
# 📄 Memproses halaman ke-65
# 📄 Memproses halaman ke-66
# 📄 Memproses halaman ke-67
# 📄 Memproses halaman ke-68
# 📄 Memproses halaman ke-69
# 📄 Memproses halaman ke-70
# 📄 Memproses halaman ke-71
# 📄 Memproses halaman ke-72
# 📄 Memproses halaman ke-73
# 📄 Memproses halaman ke-74
# 📄 Memproses halaman ke-75
# 📄 Memproses halaman ke-76
# 📄 Memproses halaman ke-77
# 📄 Memproses halaman ke-78
# 📄 Memproses halaman ke-79
# 📄 Memproses halaman ke-80
# 📄 Memproses halaman ke-81
# 📄 Memproses halaman ke-82
# 📄 Memproses halaman ke-83
# 📄 Memproses halaman ke-84
# 📄 Memproses halaman ke-85
# 📄 Memproses halaman ke-86
# 📄 Memproses halaman ke-87
# 📄 Memproses halaman ke-88
# 📄 Memproses halaman ke-89
# 📄 Memproses halaman ke-90
# 📄 Memproses halaman ke-91
# 📄 Memproses halaman ke-92
# 📄 Memproses halaman ke-93
# 📄 Memproses halaman ke-94
# 📄 Memproses halaman ke-95
# 📄 Memproses halaman ke-96
# 📄 Memproses halaman ke-97
# 📄 Memproses halaman ke-98
# 📄 Memproses halaman ke-99
# 📄 Memproses halaman ke-100
# 📄 Memproses halaman ke-101
# 📄 Memproses halaman ke-102
# 📄 Memproses halaman ke-103
# 📄 Memproses halaman ke-104
# 📄 Memproses halaman ke-105
# 📄 Memproses halaman ke-106
# 📄 Memproses halaman ke-107
# 📄 Memproses halaman ke-108
# 📄 Memproses halaman ke-109
# 📄 Memproses halaman ke-110
# 📄 Memproses halaman ke-111
# 📄 Memproses halaman ke-112
# 📄 Memproses halaman ke-113
# 📄 Memproses halaman ke-114
#                          penulis  \
# 0                        Mojiono
# 1             Rudiyana Maf 'Ulah
# 2             Indah Purnama Sari
# 3         Ahmad Fawaid Kurniawan
# 4    Mohammad Osidani Aji Wijaya
# ..                           ...
# 563               MUHAMMAD RIZAL
# 564           ACHMAD ARDI WIJAYA
# 565                   Hendriyadi
# 566                 Peni Asrurin
# 567                     Budiyono
#
#                                                  judul  \
# 0    Sifat Fisik dan Profil Gelatinisasi Tepung Uwi...
# 1    PENGARUH KONSENTRASI FLOKULAN (MAGNAFLOC LT 27...
# 2    Optimasi Penggunaan Tepung Labu Kuning dan Gum...
# 3    Kondisi Optimum Pembuatan Cup Cake Tersubstitu...
# 4    ANALISIS FINANSIAL PADA PRODUKSI ROTI TAWAR ME...
# ..                                                 ...
# 563  PENGENDALIAN KUALITAS TEMBAKAU KERING  DENGAN ...
# 564  PENGEMBANGAN PRODUK KERUPUK AMPLANG DENGAN PEN...
# 565  Analisis Faktor Yang Mempengaruhi Pembelian Te...
# 566  Karakteristik Fisik dan Sensoris Mi Kering Tep...
# 567  ALTERNATIF PEMILIHAN JENIS PAKAN SAPI MADURA D...
#
#                        pembimbing_pertama           pembimbing_kedua  \
# 0     Ir. Umi Purwandari, M.App.Sc., Ph.D          Burhan, S.TP., MT
# 1           Darimiyya Hidayati, S.TP. MP.   Ir. Muhammad Fakhry, MP.
# 2                      Dr. Umi Purwandari      Supriyanto, S.TP.,M.P
# 3                      Dr. Umi Purwandari           Burhan S.TP, M.T
# 4          Banun Dyah Probowati S.TP, Msi         Dr. Umi Purwandari
# ..                                    ...                        ...
# 563      Dr. M. Fuad Fauzul M, STP., M.Si       Ir. Moh. Fakhry., MP
# 564   Dr. Moh. Fuad Fauzul M, S.TP., M.Si   Khoirul Hidayat, ST., MT
# 565   Dr. Moh. Fuad Fauzul M, S.TP., M.Si    Khoirul Hidayat, ST.,MT
# 566  Ir. Umi Purwandari, M.App.Sc., Ph.D.  Cahyo Indarto, S.TP., M.P
# 567         Dr, Muhammad fuad FM,STP.M.Si          Dr.Ir. H.Asfan,MP
#
#                                           abstrak_indo  \
# 0    Teknologi modifikasi pada tepung non konvensio...
# 1    Kualitas gula yang dihasilkan tergantung pada ...
# 2    Program diversifikasi bahan pangan lokal dihar...
# 3    ABSTRAK\r\nBahan pangan lokal yang dapat mensu...
# 4    ABSTRAK\r\n\r\n\r\nRoti tawar merupakan makana...
# ..                                                 ...
# 563  Pengendalian kualitas merupakan sebuah upaya u...
# 564  Produk ramah lingkungan dapat mengurangi terja...
# 565  UD. Dianis merupakan industri rumah tangga yan...
# 566  ABSTRAK\n\n\n Mi merupakan makanan yang sudah ...
# 567  Abstrak\n Dalam menyediakan hijauan pakan tern...
#
#                                        abstrak_inggris
# 0    Starch modification technology has a potential...
# 1    The quality of sugar produced depends on the q...
# 2    Local food diversification program is expected...
# 3    ABSTRACT\r\nTaro which has high carbohydrate c...
# 4    Abstract\r\n\r\nBread is a popular food which ...
# ..                                                 ...
# 563  Quality control is an effort to maintain and i...
# 564  Environmentally friendly products can reduce t...
# 565  UD. Dianis is a home industry that produces tr...
# 566  ABSTRACT\n\n\nNoodles are foods that commonly ...
# 567  Abstract\nIn providing forage forage must be k...
#
# [568 rows x 6 columns]

# %% [markdown]
# ### B.Prodi Agribisnis

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def agribisnis():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 111):
        print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/3/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("agribisnis.csv", index=False)

    return df

# %%
agribisnis()
# Out:
# 📄 Memproses halaman ke-1
# 📄 Memproses halaman ke-2
# 📄 Memproses halaman ke-3
# 📄 Memproses halaman ke-4
# 📄 Memproses halaman ke-5
# 📄 Memproses halaman ke-6
# 📄 Memproses halaman ke-7
# 📄 Memproses halaman ke-8
# 📄 Memproses halaman ke-9
# 📄 Memproses halaman ke-10
# 📄 Memproses halaman ke-11
# 📄 Memproses halaman ke-12
# 📄 Memproses halaman ke-13
# 📄 Memproses halaman ke-14
# 📄 Memproses halaman ke-15
# 📄 Memproses halaman ke-16
# 📄 Memproses halaman ke-17
# 📄 Memproses halaman ke-18
# 📄 Memproses halaman ke-19
# 📄 Memproses halaman ke-20
# 📄 Memproses halaman ke-21
# 📄 Memproses halaman ke-22
# 📄 Memproses halaman ke-23
# 📄 Memproses halaman ke-24
# 📄 Memproses halaman ke-25
# 📄 Memproses halaman ke-26
# 📄 Memproses halaman ke-27
# 📄 Memproses halaman ke-28
# 📄 Memproses halaman ke-29
# 📄 Memproses halaman ke-30
# 📄 Memproses halaman ke-31
# 📄 Memproses halaman ke-32
# 📄 Memproses halaman ke-33
# 📄 Memproses halaman ke-34
# 📄 Memproses halaman ke-35
# 📄 Memproses halaman ke-36
# 📄 Memproses halaman ke-37
# 📄 Memproses halaman ke-38
# 📄 Memproses halaman ke-39
# 📄 Memproses halaman ke-40
# 📄 Memproses halaman ke-41
# 📄 Memproses halaman ke-42
# 📄 Memproses halaman ke-43
# 📄 Memproses halaman ke-44
# 📄 Memproses halaman ke-45
# 📄 Memproses halaman ke-46
# 📄 Memproses halaman ke-47
# 📄 Memproses halaman ke-48
# 📄 Memproses halaman ke-49
# 📄 Memproses halaman ke-50
# 📄 Memproses halaman ke-51
# 📄 Memproses halaman ke-52
# 📄 Memproses halaman ke-53
# 📄 Memproses halaman ke-54
# 📄 Memproses halaman ke-55
# 📄 Memproses halaman ke-56
# 📄 Memproses halaman ke-57
# 📄 Memproses halaman ke-58
# 📄 Memproses halaman ke-59
# 📄 Memproses halaman ke-60
# 📄 Memproses halaman ke-61
# 📄 Memproses halaman ke-62
# 📄 Memproses halaman ke-63
# 📄 Memproses halaman ke-64
# 📄 Memproses halaman ke-65
# 📄 Memproses halaman ke-66
# 📄 Memproses halaman ke-67
# 📄 Memproses halaman ke-68
# 📄 Memproses halaman ke-69
# 📄 Memproses halaman ke-70
# 📄 Memproses halaman ke-71
# 📄 Memproses halaman ke-72
# 📄 Memproses halaman ke-73
# 📄 Memproses halaman ke-74
# 📄 Memproses halaman ke-75
# 📄 Memproses halaman ke-76
# 📄 Memproses halaman ke-77
# 📄 Memproses halaman ke-78
# 📄 Memproses halaman ke-79
# 📄 Memproses halaman ke-80
# 📄 Memproses halaman ke-81
# 📄 Memproses halaman ke-82
# 📄 Memproses halaman ke-83
# 📄 Memproses halaman ke-84
# 📄 Memproses halaman ke-85
# 📄 Memproses halaman ke-86
# 📄 Memproses halaman ke-87
# 📄 Memproses halaman ke-88
# 📄 Memproses halaman ke-89
# 📄 Memproses halaman ke-90
# 📄 Memproses halaman ke-91
# 📄 Memproses halaman ke-92
# 📄 Memproses halaman ke-93
# 📄 Memproses halaman ke-94
# 📄 Memproses halaman ke-95
# 📄 Memproses halaman ke-96
# 📄 Memproses halaman ke-97
# 📄 Memproses halaman ke-98
# 📄 Memproses halaman ke-99
# 📄 Memproses halaman ke-100
# 📄 Memproses halaman ke-101
# 📄 Memproses halaman ke-102
# 📄 Memproses halaman ke-103
# 📄 Memproses halaman ke-104
# 📄 Memproses halaman ke-105
# 📄 Memproses halaman ke-106
# 📄 Memproses halaman ke-107
# 📄 Memproses halaman ke-108
# 📄 Memproses halaman ke-109
# 📄 Memproses halaman ke-110
#                         penulis  \
# 0              ENDAR PUSPA DESA
# 1              Aldiladese Jenri
# 2        Aji Sandya Satriyo, SP
# 3               Prima Noviyanto
# 4                  Abdus Syukur
# ..                          ...
# 542               Meilinda Sari
# 543  Chilyatun Nafisah Oktavina
# 544           I'ANATUS SHOFIYAH
# 545            Lilis Nur Azizah
# 546                      farida
#
#                                                  judul  \
# 0    PROSPEK USAHA BAKSO IKAN DI PULAU MANDANGIN KA...
# 1    Analisis Dampak Pola Kemitraan Terhadap Pendap...
# 2    Pemanfaatan Modal Sosial Usahatani Tembakau di...
# 3    ANALISIS PERILAKU KONSUMEN PADA MAHASISWA PERO...
# 4    ANALISIS KELAYAKAN DAN STRATEGI PENGEMBANGAN U...
# ..                                                 ...
# 542             Meilinda Sari\n160321100007\nAgribinis
# 543  Chilyatun Nafisah Oktavina\n160321100064\nAgri...
# 544          I'ANATUS SHOFIYAH;160321100035;AGRIBISNIS
# 545         Lilis Nur Azizah\n160321100038\nAgribisnis
# 546     Farida\n18 juni 2020\n160321100052\nAgribisnis
#
#                   pembimbing_pertama                     pembimbing_kedua  \
# 0                Ihsannudin, SP., MP          Aminah Happy M.A, SP., M.Si
# 1        Amanatuz Zuhriyah, SP., MMA              Slamet Widodo, SP., MSi
# 2             Slamet Widodo SP, M.Si                    Ihsannudin SP, MP
# 3           Slamet Widodo, SP., M.Si         Taufik Rizal Dwi AN, SP., MM
# 4       Aminah Happy M.A., SP., Msi.         Amanatuz Zuhriyah, SP., MMA.
# ..                               ...                                  ...
# 542  Novi Diana Badrut Tamami, SP.MP           Dr. Teti Sugiatri,SP.,M.Si
# 543    Dr. Teti Sugiarti, SP., M.Si.          Dr. Elys Fauziyah, SP., MP.
# 544    Dr. Teti Sugiarti, SP., M.Si.  Andrie K Sunyigono, SP., MP., Ph.D.
# 545    Dr. Teti Sugiarti, S.P., M.Si       Dr. Mardiyah Hayati, S.P., M.P
# 546       Dr. Elys Fauziyah, SP,. MP          Amanatuz Zuhriyah, SP,. MMA
#
#                                           abstrak_indo  \
# 0    ABSTRAK\r\n\tSalah satu pulau kecil yang memer...
# 1    Tujuan dari penelitian ini adalah untuk menget...
# 2    Modal sosial adalah suatu bentuk hubungan sosi...
# 3    Perilaku konsumen adalah suatu proses keputusa...
# 4    ABSTRAK\r\n\r\n\r\nKeberadaan Usaha Kecil dan ...
# ..                                                 ...
# 542
# 543
# 544          I'ANATUS SHOFIYAH;160321100035;AGRIBISNIS
# 545
# 546
#
#                                        abstrak_inggris
# 0    ABSTRACT\r\n\tOne of the small island which ne...
# 1
# 2
# 3    The consumer behavior is a decision process be...
# 4
# ..                                                 ...
# 542
# 543
# 544          I'ANATUS SHOFIYAH;160321100035;AGRIBISNIS
# 545
# 546
#
# [547 rows x 6 columns]

# %% [markdown]
# ### C.Prodi Agroteknologi

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def agroteknologi():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 117):
        print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/4/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("agroteknologi.csv", index=False)

    return df

# %%
agroteknologi()
# Out:
# 📄 Memproses halaman ke-1
# 📄 Memproses halaman ke-2
# 📄 Memproses halaman ke-3
# 📄 Memproses halaman ke-4
# 📄 Memproses halaman ke-5
# 📄 Memproses halaman ke-6
# 📄 Memproses halaman ke-7
# 📄 Memproses halaman ke-8
# 📄 Memproses halaman ke-9
# 📄 Memproses halaman ke-10
# 📄 Memproses halaman ke-11
# 📄 Memproses halaman ke-12
# 📄 Memproses halaman ke-13
# 📄 Memproses halaman ke-14
# 📄 Memproses halaman ke-15
# 📄 Memproses halaman ke-16
# 📄 Memproses halaman ke-17
# 📄 Memproses halaman ke-18
# 📄 Memproses halaman ke-19
# 📄 Memproses halaman ke-20
# 📄 Memproses halaman ke-21
# 📄 Memproses halaman ke-22
# 📄 Memproses halaman ke-23
# 📄 Memproses halaman ke-24
# 📄 Memproses halaman ke-25
# 📄 Memproses halaman ke-26
# 📄 Memproses halaman ke-27
# 📄 Memproses halaman ke-28
# 📄 Memproses halaman ke-29
# 📄 Memproses halaman ke-30
# 📄 Memproses halaman ke-31
# 📄 Memproses halaman ke-32
# 📄 Memproses halaman ke-33
# 📄 Memproses halaman ke-34
# 📄 Memproses halaman ke-35
# 📄 Memproses halaman ke-36
# 📄 Memproses halaman ke-37
# 📄 Memproses halaman ke-38
# 📄 Memproses halaman ke-39
# 📄 Memproses halaman ke-40
# 📄 Memproses halaman ke-41
# 📄 Memproses halaman ke-42
# 📄 Memproses halaman ke-43
# 📄 Memproses halaman ke-44
# 📄 Memproses halaman ke-45
# 📄 Memproses halaman ke-46
# 📄 Memproses halaman ke-47
# 📄 Memproses halaman ke-48
# 📄 Memproses halaman ke-49
# 📄 Memproses halaman ke-50
# 📄 Memproses halaman ke-51
# 📄 Memproses halaman ke-52
# 📄 Memproses halaman ke-53
# 📄 Memproses halaman ke-54
# 📄 Memproses halaman ke-55
# 📄 Memproses halaman ke-56
# 📄 Memproses halaman ke-57
# 📄 Memproses halaman ke-58
# 📄 Memproses halaman ke-59
# 📄 Memproses halaman ke-60
# 📄 Memproses halaman ke-61
# 📄 Memproses halaman ke-62
# 📄 Memproses halaman ke-63
# 📄 Memproses halaman ke-64
# 📄 Memproses halaman ke-65
# 📄 Memproses halaman ke-66
# 📄 Memproses halaman ke-67
# 📄 Memproses halaman ke-68
# 📄 Memproses halaman ke-69
# 📄 Memproses halaman ke-70
# 📄 Memproses halaman ke-71
# 📄 Memproses halaman ke-72
# 📄 Memproses halaman ke-73
# 📄 Memproses halaman ke-74
# 📄 Memproses halaman ke-75
# 📄 Memproses halaman ke-76
# 📄 Memproses halaman ke-77
# 📄 Memproses halaman ke-78
# 📄 Memproses halaman ke-79
# 📄 Memproses halaman ke-80
# 📄 Memproses halaman ke-81
# 📄 Memproses halaman ke-82
# 📄 Memproses halaman ke-83
# 📄 Memproses halaman ke-84
# 📄 Memproses halaman ke-85
# 📄 Memproses halaman ke-86
# 📄 Memproses halaman ke-87
# 📄 Memproses halaman ke-88
# 📄 Memproses halaman ke-89
# 📄 Memproses halaman ke-90
# 📄 Memproses halaman ke-91
# 📄 Memproses halaman ke-92
# 📄 Memproses halaman ke-93
# 📄 Memproses halaman ke-94
# 📄 Memproses halaman ke-95
# 📄 Memproses halaman ke-96
# 📄 Memproses halaman ke-97
# 📄 Memproses halaman ke-98
# 📄 Memproses halaman ke-99
# 📄 Memproses halaman ke-100
# 📄 Memproses halaman ke-101
# 📄 Memproses halaman ke-102
# 📄 Memproses halaman ke-103
# 📄 Memproses halaman ke-104
# 📄 Memproses halaman ke-105
# 📄 Memproses halaman ke-106
# 📄 Memproses halaman ke-107
# 📄 Memproses halaman ke-108
# 📄 Memproses halaman ke-109
# 📄 Memproses halaman ke-110
# 📄 Memproses halaman ke-111
# 📄 Memproses halaman ke-112
# 📄 Memproses halaman ke-113
# 📄 Memproses halaman ke-114
# 📄 Memproses halaman ke-115
# 📄 Memproses halaman ke-116
#                    penulis                                              judul  \
# 0              Yusriansyah  Efektifitas Pemberian Nutrisi Air Leri, Air Ke...
# 1                Nurhayati  RESPON PERTUMBUHAN VEGETATIF TANAMAN HIAS ILER...
# 2        Balia Perwitasari  Pengaruh Media Tanam Dan Nutrisi Terhadap Pert...
# 3              Adhadiyanto  UJI PUPUK SULFUR TERHADAP PERTUMBUHAN DAN HASI...
# 4        Refkie Ardiansyah  KERAGAMAN KANDUNGAN MINYAK ATSIRI BUAH CABE JA...
# ..                     ...                                                ...
# 572      ASIYATUL BADRIYAH  PENGARUH DOSIS PUPUK N, P, K TERHADAP PERTUMBU...
# 573  Merliana Dewi Astutik  Respon Pertumbuhan dan Hasil Tanaman Kolesom (...
# 574        Yeni Novitasari  Respon Tanaman Kolesom (Talinum triangulare (J...
# 575      Mar'atus Sholihah  Pengaruh Pemberian Pupuk Kandang Sapi Terhadap...
# 576            Nur Hidayah  Pengaruh Biochar Sekam Padi dan Pupuk Kandang ...
#
#                    pembimbing_pertama                     pembimbing_kedua  \
# 0    Dr. Ir. H. Ahmad Arsyadmunir, MS             Ir. Sinar Suryawati, MSi
# 1       Mustika Tripatmasari, SP.,MSi            Catur Wasonowati, SP.,MSi
# 2    Mustika Tripatmasari, SP., M.Si.         Catur Wasonowati, SP., M.Si.
# 3        Dr. Ir. RA Sidqi Zaed ZM, MS           Dr. Ir. Eko Murniyanto, MP
# 4            Ir. Sinar Suryawati M.Si               Drs.Kaswan Badami M.Si
# ..                                ...                                  ...
# 572               Ir. AMIN ZUCHRI, MP  Dr. Ir. H. AHMAD ARSYAD MUNIR, M.Si
# 573         Ir. Sinar Suryawati, M.Si    Dr. Agr. Eko Setiawan, S.P., M.Si
# 574         Ir. Sinar Suryawati, M.Si            Dr. Ir. Eko Murnianto, MP
# 575          Ir. Sinar Suryawati,M.Si   Dr. Agr. Eko Setiawan, S.P., M. Si
# 576        Ir. Slamet Supriyadi, M.Si     Dr. Ir. Ahmad Arsyad Munir, M.S.
#
#                                           abstrak_indo  \
# 0    Yusriansyah. 08.03.1.1.1.00005. Efektifitas Pe...
# 1    ABSTRAK\r\n\r\nIler (Coleus blumei) merupakan ...
# 2    Pakchoi (Brassica juncea L.) merupakan salah s...
# 3    Bawang merah merupakan salah satu komoditas un...
# 4    Cabe jamu (Piper retrofractum Vahl) merupakan ...
# ..                                                 ...
# 572  Permasalahan yang sering ditemui yaitu produks...
# 573  ABSTRAK\n\nTanaman Kolesom (Talinum triangular...
# 574  Tanaman kolesom (Talinum. triangulare (Jacq) W...
# 575  Penelitian ini bertujuan mengetahui pengaruh p...
# 576  Biochar merupakan padatan yang kaya kandungan ...
#
#                                        abstrak_inggris
# 0    Yusriansyah. 08.03.1.1.1.00005. Provision of W...
# 1    ABSTRACT\r\n\r\nIler  (Coleus scutellarioides ...
# 2    Pakchoi (Brassica juncea L.). is one kind of a...
# 3    Shallot is one commodity that is widely used v...
# 4    Java long pepper (Piper retrofractum Vahl) is ...
# ..                                                 ...
# 572  The problem that is often encountered is the p...
# 573  ABSTRACT\n\nTalinum triangulare (Jacq.) Willd ...
# 574  Colesom plants (Talinum. Triangulare (Jacq) Wi...
# 575  The objective of this study was to investigate...
# 576  Biochar is a material that rich in carbonaceou...
#
# [577 rows x 6 columns]

# %% [markdown]
# ### Ilmu Kelautan

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def kelautan():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 97):
        print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/5/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("kelautan.csv", index=False)

    return df

# %%
kelautan()
# Out:
# 📄 Memproses halaman ke-1
# 📄 Memproses halaman ke-2
# 📄 Memproses halaman ke-3
# 📄 Memproses halaman ke-4
# 📄 Memproses halaman ke-5
# 📄 Memproses halaman ke-6
# 📄 Memproses halaman ke-7
# 📄 Memproses halaman ke-8
# 📄 Memproses halaman ke-9
# 📄 Memproses halaman ke-10
# 📄 Memproses halaman ke-11
# 📄 Memproses halaman ke-12
# 📄 Memproses halaman ke-13
# 📄 Memproses halaman ke-14
# 📄 Memproses halaman ke-15
# 📄 Memproses halaman ke-16
# 📄 Memproses halaman ke-17
# 📄 Memproses halaman ke-18
# 📄 Memproses halaman ke-19
# 📄 Memproses halaman ke-20
# 📄 Memproses halaman ke-21
# 📄 Memproses halaman ke-22
# 📄 Memproses halaman ke-23
# 📄 Memproses halaman ke-24
# 📄 Memproses halaman ke-25
# 📄 Memproses halaman ke-26
# 📄 Memproses halaman ke-27
# 📄 Memproses halaman ke-28
# 📄 Memproses halaman ke-29
# 📄 Memproses halaman ke-30
# 📄 Memproses halaman ke-31
# 📄 Memproses halaman ke-32
# 📄 Memproses halaman ke-33
# 📄 Memproses halaman ke-34
# 📄 Memproses halaman ke-35
# 📄 Memproses halaman ke-36
# 📄 Memproses halaman ke-37
# 📄 Memproses halaman ke-38
# 📄 Memproses halaman ke-39
# 📄 Memproses halaman ke-40
# 📄 Memproses halaman ke-41
# 📄 Memproses halaman ke-42
# 📄 Memproses halaman ke-43
# 📄 Memproses halaman ke-44
# 📄 Memproses halaman ke-45
# 📄 Memproses halaman ke-46
# 📄 Memproses halaman ke-47
# 📄 Memproses halaman ke-48
# 📄 Memproses halaman ke-49
# 📄 Memproses halaman ke-50
# 📄 Memproses halaman ke-51
# 📄 Memproses halaman ke-52
# 📄 Memproses halaman ke-53
# 📄 Memproses halaman ke-54
# 📄 Memproses halaman ke-55
# 📄 Memproses halaman ke-56
# 📄 Memproses halaman ke-57
# 📄 Memproses halaman ke-58
# 📄 Memproses halaman ke-59
# 📄 Memproses halaman ke-60
# 📄 Memproses halaman ke-61
# 📄 Memproses halaman ke-62
# 📄 Memproses halaman ke-63
# 📄 Memproses halaman ke-64
# 📄 Memproses halaman ke-65
# 📄 Memproses halaman ke-66
# 📄 Memproses halaman ke-67
# 📄 Memproses halaman ke-68
# 📄 Memproses halaman ke-69
# 📄 Memproses halaman ke-70
# 📄 Memproses halaman ke-71
# 📄 Memproses halaman ke-72
# 📄 Memproses halaman ke-73
# 📄 Memproses halaman ke-74
# 📄 Memproses halaman ke-75
# 📄 Memproses halaman ke-76
# 📄 Memproses halaman ke-77
# 📄 Memproses halaman ke-78
# 📄 Memproses halaman ke-79
# 📄 Memproses halaman ke-80
# 📄 Memproses halaman ke-81
# 📄 Memproses halaman ke-82
# 📄 Memproses halaman ke-83
# 📄 Memproses halaman ke-84
# 📄 Memproses halaman ke-85
# 📄 Memproses halaman ke-86
# 📄 Memproses halaman ke-87
# 📄 Memproses halaman ke-88
# 📄 Memproses halaman ke-89
# 📄 Memproses halaman ke-90
# 📄 Memproses halaman ke-91
# 📄 Memproses halaman ke-92
# 📄 Memproses halaman ke-93
# 📄 Memproses halaman ke-94
# 📄 Memproses halaman ke-95
# 📄 Memproses halaman ke-96
#                     penulis  \
# 0        Rizki Ainul Fitria
# 1          muhammad ghufron
# 2             KIRNO MARJUKI
# 3          MOHAMMAD FATHONI
# 4    RENALDI SATRIA WAHYUDI
# ..                      ...
# 475       Nur Laili Ma'arif
# 476    Bisri Khairil Mu'min
# 477       Rewandy Yehezkiel
# 478    Alief Fajar Abdillah
# 479        Terry Dwiarianto
#
#                                                  judul  \
# 0    STUDI JENIS SUBSTRAT DAN HASIL TANGKAPAN RAJUN...
# 1    ESTIMASI PERBANDINGAN KARBON DIOKSIDA DALAM BA...
# 2    ANALISA KANDUNGAN GIZI DAN SENYAWA BIOAKTIF KE...
# 3    PENYUSUNAN MODEL ALGORITMA PENDUGA KONSENTRASI...
# 4    ANALISIS KANDUNGAN GIZI DAN LOGAM BERAT IKAN B...
# ..                                                 ...
# 475  Kajian Pola Arus Permukaan dan Sebaran Konsent...
# 476  ANALISIS PARAMETER LINGKUNGAN SAAT TERBENTUKNY...
# 477  Dinamika Perubahan Garis Pantai Di Pesisir Tel...
# 478  KARAKTERISTIK KONDISI OSEANOGRAFI DAN DISTRIBU...
# 479  ANALISIS PARAMETER OSEANOGRAFI UNTUK KESESUAIA...
#
#                             pembimbing_pertama  \
# 0        Prof. Dr. Ir. Muhammad Zainuri, M. Sc
# 1                zainul hidayah, Spi. M.App.Sc
# 2                      Hafiluddin, S.Pi., M.Si
# 3            Firman Farid Muhsoni, S.Pi., M.Sc
# 4                     Hafiluddin., S.Pi., M.Si
# ..                                         ...
# 475        Dr. Zainul Hidayah, S.pi., M.App.Sc
# 476          Ary Giri Dwi Kartika, S.Kel.,M.Si
# 477   Ach. Fachruddin Syah, S.Pi., M.Si., Ph.D
# 478   Ach. Fachruddin Syah, S.Pi., M.Si., Ph.D
# 479  Achmad Fahruddin Syah, S.Pi., M.Si., Ph.D
#
#                              pembimbing_kedua  \
# 0                Aries Dwi Siswanto, S.T, M.T
# 1       Maulinna Kusumo Wardhani, S.kel. M.Si
# 2                  Haryo Triajie, S.Pi., M.Si
# 3         Achmad Fachruddin Syah, S.Pi., M.Si
# 4             Prof. Dr. Ir. M. Zainuri., M.Sc
# ..                                        ...
# 475       Dr. Zainul Hidayah, S.pi., M.App.Sc
# 476
# 477  Ach. Fachruddin Syah, S.Pi., M.Si., Ph.D
# 478
# 479
#
#                                           abstrak_indo  \
# 0    ABSTRAK\r\n\r\nRajungan (Portunus pelagicus) m...
# 1    Muhammad Ghufron NRP. 08.03.4.11.00035. Estima...
# 2    Keong Bakau (Telescopium telescopium), merupak...
# 3    ABSTRAK\r\n\r\n\r\nDinamisnya pembangunan dan ...
# 4    Berbagai macam kegiatan yang berkaitan dengan ...
# ..                                                 ...
# 475  Pesisir Pantai Kenjeran merupakan kawasan yang...
# 476  ABSTRAK\n Pada tahap-tahap tertentu dalam prod...
# 477  Lingkungan pantai merupakan wilayah yang selal...
# 478  Laut Jawa (Wilayah Pengelolaan Perikanan/ WPP ...
# 479  Pulau Gili Ketapang merupakan salah satu daera...
#
#                                        abstrak_inggris
# 0    ABSTRACT\r\n\r\nSmall crab attaching (Portunus...
# 1    Muhammad Ghufron NRP. 08.03.4.11.00035. Estima...
# 2    Mangrove shells (Telescopium telescopium), are...
# 3    ABSTRACT\r\n\r\n\r\nDynamic development and ex...
# 4    A wide range of activities related to the exis...
# ..                                                 ...
# 475  Kenjeran Beach is an area that has a lot of to...
# 476  ABSTRACT\nAt certain stages in the production ...
# 477  The coastal environment is an area that is alw...
# 478  The Java Sea (Fisheries Management Area / WPP ...
# 479  has an area of around 68 hectares with a popul...
#
# [480 rows x 6 columns]

# %% [markdown]
# ### D.Prodi Manajemen SUmberdaya Perairan

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def msp():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 3):
        print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/35/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("msp.csv", index=False)

    return df

# %%
msp()
# Out:
# 📄 Memproses halaman ke-1
# 📄 Memproses halaman ke-2
#                              penulis  \
# 0                  Wizarotul Labibah
# 1                   Nur Dina Kamelia
# 2                      Ahmad Ibrahim
# 3                    Wahidah Inayati
# 4               MOH. WILDANUL JANNAH
# 5  Roihatul Jannah dan Haryo Triajie
#
#                                                judul  \
# 0  Keberadaan Mikroplastik Pada Ikan Swanggi (Pri...
# 1  KAJIAN STOK RAJUNGAN (Portunus Pelagicus) DI P...
# 2  ESTIMASI STOK KARBON PADA EKOSISTEM HUTAN MANG...
# 3  Analisis Beban Masuk Nutrien Terhadap Kelimpah...
# 4  ANALISIS DAYA DUKUNG LINGKUNGAN PERAIRAN UNTUK...
# 5  ANALISIS KANDUNGAN TIMBAL (Pb) UDANG REBON (Ac...
#
#                       pembimbing_pertama pembimbing_kedua  \
# 0             Haryo Triajie, S.Pi., M.Si
# 1  Dr. Firman Farid Muhsoni, S.Pi., M.Sc
# 2   Dr. Firman Farid Muhsoni, S.Pi. M.Sc
# 3             Dr. Akhmad Farid, S.Pi.,MT
# 4  Dr. Firman Farid Muhsoni, S.Pi., M.Sc
# 5               Haryo Triajie, S.Pi M.Pi
#
#                                         abstrak_indo  \
# 0  Mikroplastik merupakan sampah plastik yang men...
# 1  Rajungan (Portunus pelagicus) merupakan komodi...
# 2  Meningkatnya kandungan karbon dioksida (CO2) d...
# 3  Sungai Bancaran merupakan sungai yang berada d...
# 4  Desa Saobi (Pulau Sapapan, Saobi dan Bungin Ny...
# 5  Perairan Soccah merupakan lokasi nelayan menca...
#
#                                      abstrak_inggris
# 0  Microplastic is plastic waste which is degrade...
# 1  Blue Swimming Crab (Portunus pelagicus) is an ...
# 2  The increasing of carbon dioxide (CO2) in the ...
# 3  Bancaran River is a river located in Bangkalan...
# 4  Saobi Village (Sapapan Island, Saobi and Bungi...
# 5  Soccah waters are the location of fishermen lo...

# %% [markdown]
# ### E.Prodi Magister Pengelolaan Sumber Daya Alam

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def mpsda():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 2):
        print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/37/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("mpsda.csv", index=False)

    return df

# %%
mpsda()
# Out:
# 📄 Memproses halaman ke-1
#               penulis                                              judul  \
# 0  ahmad syaiful umam  KARAKTERISASI DAN KOLEKSI PLASMA NUTFAH UNTUK ...
# 1        Siti Holifah  PENGOLAHAN LIMBAH AIR REBUSAN IKAN TERI MENJAD...
# 2     Mohammad Maskur  STRATEGI PENGEMBANGAN MAKANAN DAN MINUMAN KHAS...
#
#              pembimbing_pertama                pembimbing_kedua  \
# 0     Dr. Ir. Gita Pawana, M.Si  Dr. Ir. Hj. SIti Fatimah, M.Si
# 1  Dr.Apri Arisandi,S.Pi.,M.Si.               Dr.Ir.H.Asfan,MP.
# 2   Dr. Akhmad Farid, S.Pi., MT  Dr. Apri Arisandi, S.Pi., M.Si
#
#                                         abstrak_indo  \
# 0  Madura merupakan salah satu wilayah pemasok ko...
# 1  Ikan Teri perlu penanganan serius pasca panen ...
# 2  Makanan dan minuman khas merupakan ciri dari k...
#
#                                      abstrak_inggris
# 0  Madura is one of the regions supplying horticu...
# 1  Anchovy needs serious handling after harvest b...
# 2  Typical food and drinks are characteristic of ...

# %% [markdown]
# ## Fakultas Ekonomi dan Bisnis

# %% [markdown]
# ### A.Prodi Ekonomi Pembangunan

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def EP():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 119):
        print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/6/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("EP.csv", index=False)

    return df

# %%
EP()
# Out:
# 📄 Memproses halaman ke-1
# 📄 Memproses halaman ke-2
# 📄 Memproses halaman ke-3
# 📄 Memproses halaman ke-4
# 📄 Memproses halaman ke-5
# 📄 Memproses halaman ke-6
# 📄 Memproses halaman ke-7
# 📄 Memproses halaman ke-8
# 📄 Memproses halaman ke-9
# 📄 Memproses halaman ke-10
# 📄 Memproses halaman ke-11
# 📄 Memproses halaman ke-12
# 📄 Memproses halaman ke-13
# 📄 Memproses halaman ke-14
# 📄 Memproses halaman ke-15
# 📄 Memproses halaman ke-16
# 📄 Memproses halaman ke-17
# 📄 Memproses halaman ke-18
# 📄 Memproses halaman ke-19
# 📄 Memproses halaman ke-20
# 📄 Memproses halaman ke-21
# 📄 Memproses halaman ke-22
# 📄 Memproses halaman ke-23
# 📄 Memproses halaman ke-24
# 📄 Memproses halaman ke-25
# 📄 Memproses halaman ke-26
# 📄 Memproses halaman ke-27
# 📄 Memproses halaman ke-28
# 📄 Memproses halaman ke-29
# 📄 Memproses halaman ke-30
# 📄 Memproses halaman ke-31
# 📄 Memproses halaman ke-32
# 📄 Memproses halaman ke-33
# 📄 Memproses halaman ke-34
# 📄 Memproses halaman ke-35
# 📄 Memproses halaman ke-36
# 📄 Memproses halaman ke-37
# 📄 Memproses halaman ke-38
# 📄 Memproses halaman ke-39
# 📄 Memproses halaman ke-40
# 📄 Memproses halaman ke-41
# 📄 Memproses halaman ke-42
# 📄 Memproses halaman ke-43
# 📄 Memproses halaman ke-44
# 📄 Memproses halaman ke-45
# 📄 Memproses halaman ke-46
# 📄 Memproses halaman ke-47
# 📄 Memproses halaman ke-48
# 📄 Memproses halaman ke-49
# 📄 Memproses halaman ke-50
# 📄 Memproses halaman ke-51
# 📄 Memproses halaman ke-52
# 📄 Memproses halaman ke-53
# 📄 Memproses halaman ke-54
# 📄 Memproses halaman ke-55
# 📄 Memproses halaman ke-56
# 📄 Memproses halaman ke-57
# 📄 Memproses halaman ke-58
# 📄 Memproses halaman ke-59
# 📄 Memproses halaman ke-60
# 📄 Memproses halaman ke-61
# 📄 Memproses halaman ke-62
# 📄 Memproses halaman ke-63
# 📄 Memproses halaman ke-64
# 📄 Memproses halaman ke-65
# 📄 Memproses halaman ke-66
# 📄 Memproses halaman ke-67
# 📄 Memproses halaman ke-68
# 📄 Memproses halaman ke-69
# 📄 Memproses halaman ke-70
# 📄 Memproses halaman ke-71
# 📄 Memproses halaman ke-72
# 📄 Memproses halaman ke-73
# 📄 Memproses halaman ke-74
# 📄 Memproses halaman ke-75
# 📄 Memproses halaman ke-76
# 📄 Memproses halaman ke-77
# 📄 Memproses halaman ke-78
# 📄 Memproses halaman ke-79
# 📄 Memproses halaman ke-80
# 📄 Memproses halaman ke-81
# 📄 Memproses halaman ke-82
# 📄 Memproses halaman ke-83
# 📄 Memproses halaman ke-84
# 📄 Memproses halaman ke-85
# 📄 Memproses halaman ke-86
# 📄 Memproses halaman ke-87
# 📄 Memproses halaman ke-88
# 📄 Memproses halaman ke-89
# 📄 Memproses halaman ke-90
# 📄 Memproses halaman ke-91
# 📄 Memproses halaman ke-92
# 📄 Memproses halaman ke-93
# 📄 Memproses halaman ke-94
# 📄 Memproses halaman ke-95
# 📄 Memproses halaman ke-96
# 📄 Memproses halaman ke-97
# 📄 Memproses halaman ke-98
# 📄 Memproses halaman ke-99
# 📄 Memproses halaman ke-100
# 📄 Memproses halaman ke-101
# 📄 Memproses halaman ke-102
# 📄 Memproses halaman ke-103
# 📄 Memproses halaman ke-104
# 📄 Memproses halaman ke-105
# 📄 Memproses halaman ke-106
# 📄 Memproses halaman ke-107
# 📄 Memproses halaman ke-108
# 📄 Memproses halaman ke-109
# 📄 Memproses halaman ke-110
# 📄 Memproses halaman ke-111
# 📄 Memproses halaman ke-112
# 📄 Memproses halaman ke-113
# 📄 Memproses halaman ke-114
# 📄 Memproses halaman ke-115
# 📄 Memproses halaman ke-116
# 📄 Memproses halaman ke-117
# 📄 Memproses halaman ke-118
#                          penulis  \
# 0                  Zeni Amaliyah
# 1                         suerna
# 2                    Amas Madina
# 3             Enny Wahyuningtias
# 4          ACHMAD ALVIEN AFRIADI
# ..                           ...
# 584                      Hamilah
# 585  Mochammad Raharjo Priambodo
# 586        MUHAMMAD BAKHRUL ULUM
# 587            MOHAMMAD FAHRUDIN
# 588     Sholikah Nur Aisah Putri
#
#                                                  judul  \
# 0    ANALISIS FAKTOR – FAKTOR YANG MEMPENGARUHI PEN...
# 1    Analisis Penyerapan Tenaga Kerja Pada Industri...
# 2         Analisis MInat Migrasi di Kecamatan Arosbaya
# 3    ANALISIS DETERMINAN KREDIT PELEPAS UANG UNTUK ...
# 4    ANALISIS FAKTOR-FAKTOR YANG MEMPENGARUHI PRODU...
# ..                                                 ...
# 584  PENGARUH SUKU BUNGA, INFLASI, NILAI TUKAR, DAN...
# 585  PERAN KELEMBAGAAN DALAM UPAYA PENINGKATAN PEND...
# 586  ANALISIS STRUKTUR PASAR INDUSTRI JAJANAN TRADI...
# 587  ANALISIS STRATEGI PEMBANGUNAN WISATA SENDANG B...
# 588  PENGEMBANGAN WISATA DENGAN PENDEKATAN PENGEMBA...
#
#                            pembimbing_pertama  \
# 0            Ris Yuwono Yudo Nugroho, SE, MSi
# 1    Crisanty Sutristyaningtyas Titik.S.E.,ME
# 2                      Andri Wijanarko, SE,ME
# 3              Bondan Satriawan, SE.,MEcon,St
# 4                     ANITA KRISTINA, SE, MSi
# ..                                        ...
# 584         Dr. Diah Wahyuningsih, S.E., M.Si
# 585              Henny Oktavianti, S.E., M.E.
# 586                 HENNY OKTAVIANTI.S.E.,M.E
# 587              Henny Oktavianti, S.E., M.E.
# 588            Selamet Joko Utomo, S.E., M.E.
#
#                       pembimbing_kedua  \
# 0    Bondan Satriawan, SE., MEcon.,St.
# 1                 Jakfar Sadik.S.E.,ME
# 2             Widita Kurniasari, SE,ME
# 3           Diah Wahyuningsih, SE.,Msi
# 4            WIDITA KURNIASARI, SE, ME
# ..                                 ...
# 584
# 585
# 586
# 587
# 588
#
#                                           abstrak_indo  \
# 0    ABSTRAK\r\nStudi ini dilakukan untuk mengetahu...
# 1    Dalam memperluas kesempatan tenaga kerja dapat...
# 2    ABSTRAK\r\n\r\n\r\nAmas Madina, dalam peneliti...
# 3    ABSTRAK\r\n\r\n             Permasalahan pedag...
# 4    ABSTRAK\r\nAchmad Alvien Afriadi, Analisis Fak...
# ..                                                 ...
# 584  ABSTRAK\nPenelitian ini bertujuan untuk mengan...
# 585  M Raharjo P, Peran Kelembagaan Dalam Upaya Pen...
# 586  uhammad  Bakhrul  Ulum:  Analisis  Struktur  P...
# 587  Abstrak\n\nMohammad Fahrudin 150231100011. Pro...
# 588  Tujuan penelitian ini adalah untuk bagaimana p...
#
#                                        abstrak_inggris
# 0    ABSTRACT\r\nThis study was conducted to find o...
# 1    The expanding on labor chance to get a job can...
# 2
# 3
# 4    ABSTRACT\r\n\r\nAchmad Alvien Afriadi, Analysi...
# ..                                                 ...
# 584  Abstract\nThis study aims to analyze the facto...
# 585  M Raharjo P.  Institutional Role In Efforts To...
# 586  Muhammad  Bakhrul  Ulum:  Analysis  of  Market...
# 587  Abstract\n\nMohammad Fahrudin 150231100011. De...
# 588  The purpose of this study is to develop a loca...
#
# [589 rows x 6 columns]

# %% [markdown]
# ### Prodi Manajemen

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def manajemen():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 208):
        print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/7/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("manajemen.csv", index=False)

    return df

# %%
manajemen()
# Out:
# 📄 Memproses halaman ke-1
# 📄 Memproses halaman ke-2
# 📄 Memproses halaman ke-3
# 📄 Memproses halaman ke-4
# 📄 Memproses halaman ke-5
# 📄 Memproses halaman ke-6
# 📄 Memproses halaman ke-7
# 📄 Memproses halaman ke-8
# 📄 Memproses halaman ke-9
# 📄 Memproses halaman ke-10
# 📄 Memproses halaman ke-11
# 📄 Memproses halaman ke-12
# 📄 Memproses halaman ke-13
# 📄 Memproses halaman ke-14
# 📄 Memproses halaman ke-15
# 📄 Memproses halaman ke-16
# 📄 Memproses halaman ke-17
# 📄 Memproses halaman ke-18
# 📄 Memproses halaman ke-19
# 📄 Memproses halaman ke-20
# 📄 Memproses halaman ke-21
# 📄 Memproses halaman ke-22
# 📄 Memproses halaman ke-23
# 📄 Memproses halaman ke-24
# 📄 Memproses halaman ke-25
# 📄 Memproses halaman ke-26
# 📄 Memproses halaman ke-27
# 📄 Memproses halaman ke-28
# 📄 Memproses halaman ke-29
# 📄 Memproses halaman ke-30
# 📄 Memproses halaman ke-31
# 📄 Memproses halaman ke-32
# 📄 Memproses halaman ke-33
# 📄 Memproses halaman ke-34
# 📄 Memproses halaman ke-35
# 📄 Memproses halaman ke-36
# 📄 Memproses halaman ke-37
# 📄 Memproses halaman ke-38
# 📄 Memproses halaman ke-39
# 📄 Memproses halaman ke-40
# 📄 Memproses halaman ke-41
# 📄 Memproses halaman ke-42
# 📄 Memproses halaman ke-43
# 📄 Memproses halaman ke-44
# 📄 Memproses halaman ke-45
# 📄 Memproses halaman ke-46
# 📄 Memproses halaman ke-47
# 📄 Memproses halaman ke-48
# 📄 Memproses halaman ke-49
# 📄 Memproses halaman ke-50
# 📄 Memproses halaman ke-51
# 📄 Memproses halaman ke-52
# 📄 Memproses halaman ke-53
# 📄 Memproses halaman ke-54
# 📄 Memproses halaman ke-55
# 📄 Memproses halaman ke-56
# 📄 Memproses halaman ke-57
# 📄 Memproses halaman ke-58
# 📄 Memproses halaman ke-59
# 📄 Memproses halaman ke-60
# 📄 Memproses halaman ke-61
# 📄 Memproses halaman ke-62
# 📄 Memproses halaman ke-63
# 📄 Memproses halaman ke-64
# 📄 Memproses halaman ke-65
# 📄 Memproses halaman ke-66
# 📄 Memproses halaman ke-67
# 📄 Memproses halaman ke-68
# 📄 Memproses halaman ke-69
# 📄 Memproses halaman ke-70
# 📄 Memproses halaman ke-71
# 📄 Memproses halaman ke-72
# 📄 Memproses halaman ke-73
# 📄 Memproses halaman ke-74
# 📄 Memproses halaman ke-75
# 📄 Memproses halaman ke-76
# 📄 Memproses halaman ke-77
# 📄 Memproses halaman ke-78
# 📄 Memproses halaman ke-79
# 📄 Memproses halaman ke-80
# 📄 Memproses halaman ke-81
# 📄 Memproses halaman ke-82
# 📄 Memproses halaman ke-83
# 📄 Memproses halaman ke-84
# 📄 Memproses halaman ke-85
# 📄 Memproses halaman ke-86
# 📄 Memproses halaman ke-87
# 📄 Memproses halaman ke-88
# 📄 Memproses halaman ke-89
# 📄 Memproses halaman ke-90
# 📄 Memproses halaman ke-91
# 📄 Memproses halaman ke-92
# 📄 Memproses halaman ke-93
# 📄 Memproses halaman ke-94
# 📄 Memproses halaman ke-95
# 📄 Memproses halaman ke-96
# 📄 Memproses halaman ke-97
# 📄 Memproses halaman ke-98
# 📄 Memproses halaman ke-99
# 📄 Memproses halaman ke-100
# 📄 Memproses halaman ke-101
# 📄 Memproses halaman ke-102
# 📄 Memproses halaman ke-103
# 📄 Memproses halaman ke-104
# 📄 Memproses halaman ke-105
# 📄 Memproses halaman ke-106
# 📄 Memproses halaman ke-107
# 📄 Memproses halaman ke-108
# 📄 Memproses halaman ke-109
# 📄 Memproses halaman ke-110
# 📄 Memproses halaman ke-111
# 📄 Memproses halaman ke-112
# 📄 Memproses halaman ke-113
# 📄 Memproses halaman ke-114
# 📄 Memproses halaman ke-115
# 📄 Memproses halaman ke-116
# 📄 Memproses halaman ke-117
# 📄 Memproses halaman ke-118
# 📄 Memproses halaman ke-119
# 📄 Memproses halaman ke-120
# 📄 Memproses halaman ke-121
# 📄 Memproses halaman ke-122
# 📄 Memproses halaman ke-123
# 📄 Memproses halaman ke-124
# 📄 Memproses halaman ke-125
# 📄 Memproses halaman ke-126
# 📄 Memproses halaman ke-127
# 📄 Memproses halaman ke-128
# 📄 Memproses halaman ke-129
# 📄 Memproses halaman ke-130
# 📄 Memproses halaman ke-131
# 📄 Memproses halaman ke-132
# 📄 Memproses halaman ke-133
# 📄 Memproses halaman ke-134
# 📄 Memproses halaman ke-135
# 📄 Memproses halaman ke-136
# 📄 Memproses halaman ke-137
# 📄 Memproses halaman ke-138
# 📄 Memproses halaman ke-139
# 📄 Memproses halaman ke-140
# 📄 Memproses halaman ke-141
# 📄 Memproses halaman ke-142
# 📄 Memproses halaman ke-143
# 📄 Memproses halaman ke-144
# 📄 Memproses halaman ke-145
# 📄 Memproses halaman ke-146
# 📄 Memproses halaman ke-147
# 📄 Memproses halaman ke-148
# 📄 Memproses halaman ke-149
# 📄 Memproses halaman ke-150
# 📄 Memproses halaman ke-151
# 📄 Memproses halaman ke-152
# 📄 Memproses halaman ke-153
# 📄 Memproses halaman ke-154
# 📄 Memproses halaman ke-155
# 📄 Memproses halaman ke-156
# 📄 Memproses halaman ke-157
# 📄 Memproses halaman ke-158
# 📄 Memproses halaman ke-159
# 📄 Memproses halaman ke-160
# 📄 Memproses halaman ke-161
# 📄 Memproses halaman ke-162
# 📄 Memproses halaman ke-163
# 📄 Memproses halaman ke-164
# 📄 Memproses halaman ke-165
# 📄 Memproses halaman ke-166
# 📄 Memproses halaman ke-167
# 📄 Memproses halaman ke-168
# 📄 Memproses halaman ke-169
# 📄 Memproses halaman ke-170
# 📄 Memproses halaman ke-171
# 📄 Memproses halaman ke-172
# 📄 Memproses halaman ke-173
# 📄 Memproses halaman ke-174
# 📄 Memproses halaman ke-175
# 📄 Memproses halaman ke-176
# 📄 Memproses halaman ke-177
# 📄 Memproses halaman ke-178
# 📄 Memproses halaman ke-179
# 📄 Memproses halaman ke-180
# 📄 Memproses halaman ke-181
# 📄 Memproses halaman ke-182
# 📄 Memproses halaman ke-183
# 📄 Memproses halaman ke-184
# 📄 Memproses halaman ke-185
# 📄 Memproses halaman ke-186
# 📄 Memproses halaman ke-187
# 📄 Memproses halaman ke-188
# 📄 Memproses halaman ke-189
# 📄 Memproses halaman ke-190
# 📄 Memproses halaman ke-191
# 📄 Memproses halaman ke-192
# 📄 Memproses halaman ke-193
# 📄 Memproses halaman ke-194
# 📄 Memproses halaman ke-195
# 📄 Memproses halaman ke-196
# 📄 Memproses halaman ke-197
# 📄 Memproses halaman ke-198
# 📄 Memproses halaman ke-199
# 📄 Memproses halaman ke-200
# 📄 Memproses halaman ke-201
# 📄 Memproses halaman ke-202
# 📄 Memproses halaman ke-203
# 📄 Memproses halaman ke-204
# 📄 Memproses halaman ke-205
# 📄 Memproses halaman ke-206
# 📄 Memproses halaman ke-207
#                       penulis  \
# 0                     SATIYAH
# 1                     Faishal
# 2             Wahyu Kurniawan
# 3      Muhammad Zakaria Utomo
# 4     Hendri Wahyudi Prayitno
# ...                       ...
# 1026           Husnul Hotimah
# 1027          Uswatun Hasanah
# 1028              ACH FATHONI
# 1029     INTAN YULLIA NINGSIH
# 1030        Widha Deby Andrea
#
#                                                   judul  \
# 0     PENGARUH FAKTOR-FAKTOR PELATIHAN DAN PENGEMBAN...
# 1     ANALISIS PERSEPSI BRAND ASSOCIATION MENURUT PE...
# 2     PENGARUH GAYA KEPEMIMPINAN DEMOKRATIK TERHADAP...
# 3     Pengukuran Website Quality Pada Situs Sistem A...
# 4     PENGARUH KEPEMIMPINAN DAN KOMPENSASI TERHADAP ...
# ...                                                 ...
# 1026  Analisis Cost Volume Profit Untuk Menentukan T...
# 1027  Pengaruh Pelatihan Dan Kompensasi Terhadap Pro...
# 1028  PERAN SERVICE PERFORMANCE DAN CLIMATE ORGANIZA...
# 1029  BAURAN PROMOSI PADA DEALER YAMAHA TRETAN MOTOR...
# 1030  Peran Teor Motivasi Herzberg Sebagai Mediator ...
#
#                                  pembimbing_pertama  \
# 0                Dra. Hj. S. Anugrahini Irawati, MM
# 1                                   Nurita Andriani
# 2                    Dr. Dra. Hj. Iriani Ismail, MM
# 3                       Dr. Ir. Nurita Andriani, MM
# 4                 Dra. Hj. S Anugrahini Irawati, MM
# ...                                             ...
# 1026            Hj. Evaliati Amaniyah, S.E., M.S.M.
# 1027  Dr. Raden Mas Mochammad  Wispandono S.E ., MS
# 1028                YUDHI PRASETYA MADA, S.E., M.M.
# 1029                 DR. MOHAMMAD ARIEF, S.E., M.M.
# 1030             Mochammad Isa Anshori, S.E., M.Si.
#
#                         pembimbing_kedua  \
# 0        Helmi Buyung Aulia,S,ST.SE,M.MT
# 1                   Yustina Chrismardani
# 2     Dra. Hj. S. Anugrahini Irawati, MM
# 3              Nirma Kurriwati, SP, M.Si
# 4         Helmi Buyung Aulia,S,ST,SE,.MT
# ...                                  ...
# 1026
# 1027
# 1028
# 1029
# 1030
#
#                                            abstrak_indo  \
# 0     ABSTRAK\r\nSatiyah, Pengaruh Faktor-faktor Pel...
# 1     Tujuan penelitian ini adalah untuk mengetahui ...
# 2
# 3     Aplikasi nyata pemanfaatan teknologi informasi...
# 4     Abstrak\r\nPenelitian ini menggunakan metode k...
# ...                                                 ...
# 1026  ABSTRAK\nPenelitian ini bertujuan untuk menget...
# 1027  ABSTRAK\nUswatun Hasanah, 160211100291, Pengar...
# 1028  ABSTRAK\nTujuan dari penelitian ini adalah unt...
# 1029  ABSTRAK\nPenelitian ini bertujuan: (1) Untuk m...
# 1030  Penelitian ini bertujuan untuk dapat mengetahu...
#
#                                         abstrak_inggris
# 0     ABSTRACT\r\n\r\nIn an effort to increase labor...
# 1     This study wanted to know the brand associatio...
# 2
# 3     Academic portal system in University of Trunoj...
# 4     Abstract\r\nThis research use quantitative met...
# ...                                                 ...
# 1026  ABSTRACT\nThis study aims to determine the cal...
# 1027  ABSTRACT\nUswatun Hasanah, 160211100291, The E...
# 1028  ABSTRACK\n           The purpose of this study...
# 1029  ABSTRACK\nThis study aims: (1) To find out whe...
# 1030  This study aims to find out about the effect o...
#
# [1031 rows x 6 columns]

# %% [markdown]
# ### Akutansi

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def akutansi():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 178):
        # print(f"📄 Memproses halaman ke-{i}")  ← Dihilangkan atau dikomentari
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/8/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("akutansi.csv", index=False)

    return df

# %%
akutansi()
# Out:
#                   penulis                                              judul  \
# 0              Nida Qolbi  PENTINGNYA KOMPETENSI PEJABAT PENGADAAN BARANG...
# 1        Rr. ALVIN SHARAS  ANALISIS PERLAKUAN AKUNTANSI TABUNGAN DENGAN S...
# 2             MOH. MUKROM  PERSEPSI MAHASISWA TENTANG MODEL PEMBELAJARAN ...
# 3      KARTIKA RUSNINDITA  ANALISIS FUNGSI LAKIP SEBAGAI PENGUKURAN KINER...
# 4    DEWI AGUS NORFITRIAH  PENGARUH FAKTOR-FAKTOR TINGKAT KESULITAN DALAM...
# ..                    ...                                                ...
# 878        Suci Indahsari  PENGELOLAAN DAN PEMANFAATAN DANA KAPITASI  (St...
# 879       Nafisatun Nufus  ANALISIS FAKTOR FAKTOR YANG MEMPENGARUHI KUALI...
# 880         Anis Nurlaeli  ANALISIS PENGARUH SISTEM PENGENDALIAN INTERNAL...
# 881         Ernia Juniati  Pengaruh Kualitas Sumber Daya Manusia, Pemaham...
# 882     Eka Septia  Putri  PENGARUH LAPORAN ARUS KAS, LABA BERSIH DAN SIZ...
#
#                                pembimbing_pertama  \
# 0                Mohammad Djasuli,SE., M.Si., QIA
# 1    Prof. Dr. H. M. Nizarul Alim, SE., M.Si., Ak
# 2                     RITA YULIANA, SE., MSA., Ak
# 3                             JUNAIDI SE,M.Si.,Ak
# 4                  ANIS WULANDARI, SE., M.SA., Ak
# ..                                            ...
# 878             Citra Nurhayati, S.E.,MA.,Ak.,CA.
# 879     Dr. Siti Musyarofah, S.E., M.Si., Ak., CA
# 880      Dr. Siti Musyarofah, S.E., M.Si., AK.,CA
# 881          Citra Nurhayati, S.E., M.A., Ak., CA
# 882    Alexander  Anggono,  S.E. ,  M.Si . ,  PhD
#
#                          pembimbing_kedua  \
# 0    Gita Arasy Harwida,SE.,Ak.,M.Tax,QIA
# 1             Rita Yuliana, SE,M.S.A., Ak
# 2                  JUNAIDI, SE., MSi., Ak
# 3                    NURHAYATI SE,MSA.,Ak
# 4         NURUL KOMPYURINI, SE., Ak., MAk
# ..                                    ...
# 878
# 879
# 880
# 881
# 882
#
#                                           abstrak_indo  \
# 0    Abstrak : Pentingnya Kompetensi Pejabat Pengad...
# 1    ABSTRAK\r\n\r\nWadiah telah berkembang dalam d...
# 2    ABSTRAK\r\n\r\nKeberadaan beasiswa di Fakultas...
# 3    ABSTRAK\r\n\r\nPenelitian ini bertujuan untuk ...
# 4    Agus Norfitriah, Dewi. 2012. Pengaruh Faktor-F...
# ..                                                 ...
# 878  ABSTRAK\nPengelolaan dan pemanfaatan dana kapi...
# 879  ABSTRAK\nPenelitian ini bertujuan untuk yang 1...
# 880  ABSTRAK\n \nPenelitian ini bertujuan untuk men...
# 881  Penelitian ini bertujuan untuk mengetahui peng...
# 882  ABSTRAK\n \nEka Septia Putri, Pengaruh Laporan...
#
#                                        abstrak_inggris
# 0    ABSTRAK\r\nQolbi, Nida 2012 “ The Importance C...
# 1    ABSTRACT\r\n\r\nWadiah has grown in world syar...
# 2    ABSTRACT\r\n\r\nExistence scholarship at the e...
# 3    ABSTRACT\r\n\r\nThis study is aimed to know ho...
# 4    Agus Norfitriah, Dewi. 2012. Influence of Fact...
# ..                                                 ...
# 878  ABSTRACT\n Management and utilization of capit...
# 879  ABSTRACT\nThis study aims to 1.) Analyze the i...
# 880  ABSTRACT\n\n The purpose of this research are ...
# 881  This study aims to determine the effect of the...
# 882  ABSTRACT \n \nEka Septia Putri, The Effect of ...
#
# [883 rows x 6 columns]

# %% [markdown]
# ### D3 Akutansi

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def d3akutansi():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 32):
        # print(f"📄 Memproses halaman ke-{i}")  ← Dihilangkan atau dikomentari
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/21/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("d3akutansi.csv", index=False)

    return df

# %%
d3akutansi()
# Out:
#                            penulis  \
# 0    novarika yunia kusuma wardani
# 1           SITI LATIFATUL KAMALIA
# 2       Priya Agung Budi Wicaksono
# 3                   RB ALIF REZA K
# 4                  Choirur Rozikin
# ..                             ...
# 146      Vira Damara Putri Suganda
# 147                  FAIRUSUL UMAM
# 148                   SAIPUL BAHRI
# 149            NURUL AULIA NINGSIH
# 150                  IMRON ROSYADI
#
#                                                  judul  \
# 0    Sistem Informasi Akuntansi Upah kepada Pegawai...
# 1    EVALUASI PEMOTONGAN, PENYETORAN DAN PELAPORAN ...
# 2    analisis pengendalian internal terhadap peneri...
# 3    Peranan Pendapatan Asli Daerah dalam Menunjang...
# 4    ANALISIS PROSES PEMOTONGAN, PENYETORAN, DAN PE...
# ..                                                 ...
# 146  Evaluasi Sistem Penerimaan Kas Pada Perusahaan...
# 147  EVALUASI PENERAPAN PEMOTONGAN DAN  PENYETORAN ...
# 148  ANALISIS SISTEM DAN PROSEDUR IZIN MENDIRKAN BA...
# 149  PENCATATAN LAPORAN KEUANGAN BERBASIS STANDAR A...
# 150  EVALUASI KINERJA ORGANISASI INSPEKTORAT PEMERI...
#
#                              pembimbing_pertama  \
# 0             Nurul Kompyurini, S.E., M.Ak., Ak
# 1     Yudhanta Sambharakreshna, S.E., M.Si., Ak
# 2               Citra Nurhayati, S. E., MA., Ak
# 3               Nurul Herawati, S.E., M.Si., Ak
# 4             Nurul Kompyurini, S.E., M.Ak., Ak
# ..                                          ...
# 146      Yuni Rimawati, S.E., M.S.Ak., Ak., CA.
# 147           Muhammad Asim Asy’ari, SE., M. Ak
# 148  Achdiar Redy Setiawan, S.E., MSA., Ak., CA
# 149            FARIYANA KUSUMAWATI, S.E., M.Sc.
# 150    Adi Darmawan Ervanto, S.E., MA., Ak., CA
#
#                                   pembimbing_kedua  \
# 0    Anita Carolina, S.E., MbusAdv., Ak., QIA, CA.
# 1      Rindah Febriana Suryawati, S.E., M.Acc., Ak
# 2    Anita Carolina. S. E., MbusAdv., Ak., QIA, CA
# 3         Rahmat Zuhdi, S.E., M.SA., CA., Ak., QIA
# 4                 Erfan Muhammad, S.E., M.Ak., CPA
# ..                                             ...
# 146
# 147
# 148
# 149
# 150
#
#                                           abstrak_indo  \
# 0    PT PELINDO III (Persero) cabang Tanjung Perak ...
# 1    Evaluasi pemotongan, penyetoran dan pelaporan ...
# 2    ABSTRAK\r\n\r\nPriya Agung Budi Wicaksono, Ana...
# 3    Pemerintah daerah sebagai induk sistem pemerin...
# 4    Abstrak\r\n\r\nChoirur Rozikin, Analisis Prose...
# ..                                                 ...
# 146  Vira Damara Putri Suganda, Evaluasi Sistem Pen...
# 147  Fairusul Umam, Evaluasi Penerapan Pemotongan, ...
# 148  SISTEM DAN PROSEDUR PEROLEHAN IZIN MENDIRIKAN ...
# 149  PENCATATAN LAPORAN KEUANGAN BERBASIS STANDAR A...
# 150  Penelitian ini berjudul evaluasi kinerja organ...
#
#                                        abstrak_inggris
# 0    PT PELINDO III (Persero) Tanjung Perak Surabay...
# 1    Evaluation of cutting, depositing and reportin...
# 2    ABSTRACT\r\n\r\nPriya Agung Budi Wicaksono, An...
# 3    Local government as the main system of governm...
# 4    Abstract\r\n\r\nChoirur Rozikin, Analysis of D...
# ..                                                 ...
# 146  Vira Damara Putri Suganda, Evaluation of Cash ...
# 147  Fairusul Umam, Evaluation Application Cuts, Ta...
# 148  SYSTEM AND PROCEDURES FOR PERMISSION OF LICENS...
# 149  PENCATATAN LAPORAN KEUANGAN BERBASIS STANDAR A...
# 150  The study titles is the evaluation of the orga...
#
# [151 rows x 6 columns]

# %% [markdown]
# Magister Manajemen

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def magistermanajemen():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 15):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/22/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("magistermanajemen.csv", index=False)

    return df

# %%
magistermanajemen()
# Out:
#                      penulis  \
# 0       Jaka Ardiansyah, S.E
# 1    Dian Yunita Syaiful, SE
# 2      VERY ANDRIANINGSIH,SE
# 3   Mochammad Mangkus Efendi
# 4        AHMAD MUSTAIN SALEH
# ..                       ...
# 65             Nanto Purnomo
# 66         FITRIYAH S. Fil.I
# 67         YOLA PRATAMA, ST.
# 68                Kristianto
# 69                     Zaini
#
#                                                 judul  \
# 0   PENGARUH INFLASI, NILAI TUKAR RUPIAH DAN TINGK...
# 1   Pengaruh Current Ratio, Debt To Equity Ratio, ...
# 2   Pengaruh  Profitabilitas, Likuiditas, dan Stru...
# 3   PENGARUH KUALITAS PELAYANAN TERHADAP LOYALITAS...
# 4   STRATEGI REKRUTMEN DAN SELEKSI \r\nUNTUK MENIN...
# ..                                                ...
# 65  Analisis Kualitas Website Dan Reputasi Vendor ...
# 66  STRATEGI PENGEMBANGAN SUMBER DAYA MANUSIA  DEN...
# 67  ANALISIS QUALITY OF WORK LIFE TERHADAP ORGANIZ...
# 68  PENGARUH KOMUNIKASI DAN KONFLIK INTERPERSONAL ...
# 69  ZAINI. 2019. Kompetensi Pengelola dalam Pengel...
#
#                          pembimbing_pertama  \
# 0          Dr. Chairul Anam, Drs.Ec., M.Kes
# 1        Dr.  Chairul Anam, Drs. Ec., M.Kes
# 2             Dr. Drs. Chairul Anam, M. Kes
# 3               Dr.H. Pribanus Wantara., MM
# 4    Dr. Muhammad Alkirom Wildan, SE., M.Si
# ..                                      ...
# 65               Dr. Mohammad Arief, SE.,MM
# 66         Dr. Hj. Iriani Ismail, Dra., M.M
# 67   Dr. Muhammad Alkirom Wildan, SE., MSi.
# 68        Dr. RM. Moch. Wispandono, SE, MS.
# 69  Dr. Muhammad Alkirom Wildan. S.E., M.Si
#
#                                pembimbing_kedua  \
# 0             Dr. H. Pribanus Wantara, Drs., MM
# 1   Dr. Raden M. Mochammad Wispandono, S.E., MS
# 2          Dr. Muhammad Alkirom Wildan, SE. MSi
# 3             Dr. H. Muh. Syarif. Drs. Ec.,M.Si
# 4               Dr. Hj. Iriani Ismail, Dra., MM
# ..                                          ...
# 65           Dr. H. Pribanus Wantara, Drs., M.M
# 66          Dr. H. Muh. Syarif, Drs. E.c., M.Si
# 67                Dr. Ir. Nurita Andriani, M.M.
# 68         Dr. H. Pribanus Wantara, Drs., MM ..
# 69        Dr. A Yahya Surya Winata. S.E., M. Si
#
#                                          abstrak_indo  \
# 0   Penelitian ini bertujuan untuk mengetahui peng...
# 1   Return atau hasil investasi merupakan tujuan u...
# 2   Tujuan penelitian ini adalah untuk mengetahui ...
# 3   Penelitian ini ingin mensinergikan tiga variab...
# 4   ABSTRAK\r\nMUSTAIN, A. 2015. STRATEGI REKRUTME...
# ..                                                ...
# 65  Penelitian ini bertujuan untuk menganalisis ke...
# 66  Penelitian ini merupakan penelitian deskriptif...
# 67  Penelitian ini bertujuan untuk mengetahui sebe...
# 68  ABSTRAK\n\nKristianto. Pengaruh Komunikasi dan...
# 69
#
#                                       abstrak_inggris
# 0   This Research aimed to analyzed the effect of ...
# 1   Return or the return on investment is a prime ...
# 2   Research approach used in this research is the...
# 3   Abstract\r\n\r\n\r\nThis study wants to synerg...
# 4   MUSTAIN, A.  2015.  HIRING AND SELECTION TO IM...
# ..                                                ...
# 65  This study aims to analyze online purchasing d...
# 66  The population is Civil Servants (PNS) in the ...
# 67  The aims of this study are to determine the ef...
# 68  ABSTRACT\n\nResearcher takes title in this res...
# 69  ZAINI. 2019. Management Competence in the Mana...
#
# [70 rows x 6 columns]

# %% [markdown]
# Magister Akutansi

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def magisterakutansi():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 20):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/25/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("magisterakutansi.csv", index=False)

    return df

# %%
magisterakutansi()
# Out:
#                   penulis                                              judul  \
# 0     RILLA IZZATUL HAQQI  LIKUIDITAS DAN PROFITABILITAS DIGUNAKAN UNTUK ...
# 1     ANNISA MAULA HIKMAH  PERSEPSI PEJABAT PUBLIK TERHADAP GRATIFIKASI P...
# 2           Yahya Rochman  PENGARUH KOMPETENSI, TEKANAN KETAATAN, PENGALA...
# 3                  HARIRI  ANALISIS KECURANGAN LAPORAN KEUANGAN PERUSAHAA...
# 4        Imam Agus Faisol  PENGARUH PENERAPAN E-PROCUREMENT TERHADAP PENC...
# ..                    ...                                                ...
# 88              SUGIYANTO  PENGARUH BEBAN KERJA, SKEPTISME PROFESIONAL, I...
# 89       Elita Aprilianty  SIKAP, NORMA SUBJEKTIF, PERSEPSI KONTROL PERIL...
# 90  Rudy Mikiyanto Kusumo  MENDETEKSI INDIKASI FRAUD PADA LAPORAN KEUANGA...
# 91   Nur Endah Rochmawati  IMPLEMENTASI GOOD CORPORATE GOVERNANCE SEBAGAI...
# 92                 Suyono     PENENTUAN FEE AUDIT PADA KANTOR AKUNTAN PUBLIK
#
#                                   pembimbing_pertama  \
# 0        Prof. Dr. H. Moh. Nizarul A, SE., M.Si., Ak
# 1       Prof. Dr. H. M. Nizarul Alim,  SE, M.Si., Ak
# 2              Dr. Bambang Haryadi, SE.,M.Si.,Ak.,CA
# 3     Prof. Dr. M. Nizarul Alim, SE., M.Si., Ak., CA
# 4                         Dr. Tarjo, SE., M.Si., CFE
# ..                                               ...
# 88           Dr. Bambang Haryadi, S.E., M.Si, Ak, CA
# 89  Dr. Bambang Haryadi, S.E., M.Si., Ak., CA., CFrA
# 90                        Dr. Tarjo, S.E., M.Si, CFE
# 91                        Dr. Tarjo, SE., M.Si., CFE
# 92           Dr. Bambang Haryadi, SE., M.Si., Ak. CA
#
#                              pembimbing_kedua  \
# 0                  Dr. Tarjo, SE., M.SI., CFE
# 1   Dr. Bambang Haryadi, SE., M.Si., Ak., CPA
# 2                Dr. Prasetyono, SE.,M.Si.,Ak
# 3                  Dr. Tarjo, SE., M.Si., CFE
# 4   Dr. Siti Musyarofah, S.E., M.Si., Ak., CA
# ..                                        ...
# 88        Alexander Anggono, SE., M.Si., Ph.D
# 89      Dr. Prasetyono, SE., M.Si., Ak., CFrA
# 90  Dr. Bambang Haryadi, S.E., M.Si., Ak., Ak
# 91    Dr. Siti Musyarofah, SE., M.Si., Ak. CA
# 92    Dr. Siti Musyarofah, SE., M.Si., Ak. CA
#
#                                          abstrak_indo  \
# 0   Penelitian ini bertujuan untuk mengetahui rasi...
# 1   UU No 20 Tahun 2001 menyebutkan  bahwa  gartif...
# 2   Tujuan dari penelitian ini adalah untuk mengan...
# 3   Abstrak-Penelitian ini bertujuan untuk mendete...
# 4   Imam Agus Faisol, Analisis Penerapan e-procure...
# ..                                                ...
# 88  Tujuan penelitian ini yaitu untuk mendapatkan ...
# 89  Tujuan dari penelitian ini adalah untuk menget...
# 90  Umumnya keterjadian kebangkrutan beriringan de...
# 91  Perkembangan kondisi perbankan di Indonesia te...
# 92  Penelitian ini dilakukan untuk mengetahui pene...
#
#                                       abstrak_inggris
# 0   This study aims to determine the financial rat...
# 1   Law No. 20 of 2001 stipulates that gartifikasi...
# 2   The purpose of this study was to analyze the e...
# 3   Abstract-This research aims to detect fraudule...
# 4   Imam Agus Faisol, Analyze Impact of Implementa...
# ..                                                ...
# 88  The purpose of this study is to obtain empiric...
# 89  The purpose of this study was to find out how ...
# 90  Generally bankruptcy coincides with fraud. As ...
# 91  The development of banking conditions in Indon...
# 92  This research was conducted to determine the d...
#
# [93 rows x 6 columns]

# %% [markdown]
# D3 Enterpreneurship

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def d3enterpreneurship():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 16):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/26/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("d3enterpreneurship.csv", index=False)

    return df

# %%
d3enterpreneurship()
# Out:
#                    penulis                                              judul  \
# 0    Ramdhani Febriyansyah     LAPORAN KERJA USAHA DI\nPERUSAHAAN “GOOD.DEAR”
# 1   SITI FARIDATUL HASANAH  PENINGKATAN KUALITAS PRODUK PADA UD. UBER JAYA...
# 2              ANIK RIYANI  ANALISIS KUALITAS TENAGA KERJA PEMASARAN \nDI ...
# 3   PRADINA EKA ANUGRAHENY  LAPORAN KERJA USAHA \nDI \nPABRIK TAHU UD. SUM...
# 4        DWI LAILI SYAFAAH  STRATEGI PEMASARAN PADA PERUSAHAAN\nCV.PETIS M...
# ..                     ...                                                ...
# 67            ERNI YUSNITA  Analisis Peranan Modal Kerja Terhadap Peningka...
# 68   Desy Syska Nur Aisyah  EFEKTIFITAS SISTEM MONITORING PADA RUMAH MAKAN...
# 69           Nuruz Zakiyah  PROSES REKRUITMEN KARYAWAN DI PT. MADURA CONSU...
# 70   Karina Nurul Komariah  PERANAN PENILAIAN PRESTASI KERJA DALAM MENINGK...
# 71       RIZKY ALANDO ARIF  KOMUIKASI PEMASARAN DALAM MENARIK KLIEN GUNA M...
#
#                  pembimbing_pertama pembimbing_kedua  \
# 0   Drs. Ec. Bambang Sudarsono, M.M
# 1             Saniman, SE., M.PSDM.
# 2         Drs. Ec. Mudji Kuswinarno
# 3   Drs. Ec. Bambang Sudarsono. MM.
# 4    Drs.Ec. Mudji Kuswinarno, M.Si
# ..                              ...              ...
# 67  R. Gatot Heru Pranjoto, SE., MM
# 68                  Faidal, SE., MM
# 69              Saniman., SE.M.PSDM
# 70  R. Gatot Heru Pranjoto, SE., MM
# 71             DARUL ISLAM, SE., MM
#
#                                          abstrak_indo  \
# 0   ABSTRAK\n Ramdhani Febriyansyah, 2016. Laporan...
# 1   ABSTRAK\n Siti Faridatul Hasanah, “Peningkatan...
# 2   ABSTRAK\n\n Anik Riyani, “Analisis Kualitas Te...
# 3   ABSTRAK\nPradina Eka Anugraheny (130271100002)...
# 4   ABSTRAK\nDwi laili Syafaah, Strategi Pemasaran...
# ..                                                ...
# 67  ABSTRAK\n\nModal kerja menjadi faktor yang san...
# 68  ABSTRAK\n“Analisis Kepuasan Konsumen Rumah Mak...
# 69  ABSTRAK\n\nNuruz Zakiyah, 160271100013. Proses...
# 70  Penelitian ini dilatarbelakangi dari adanya pe...
# 71  Televisi adalah media masa yang sering digunak...
#
#                                       abstrak_inggris
# 0   ABSTRACT\nRamdhani Febriyansyah, 2016. Busines...
# 1   ABSTRACT\nSiti Faridatul Hasanah, "Improved qu...
# 2   ABSTRACT\n\n Anik Riyani, “Analysis of Quality...
# 3   ABSTRACT\nPradina Eka Anugraheny (130271100002...
# 4   ABSTRACT\n\n Dwi Laili Syafaah, Marketing Stra...
# ..                                                ...
# 67  ABSTRACT\n\nWorking capital is a very importan...
# 68  ABSTRACK "Analysis of Satisfaction of Tera Bul...
# 69  ABSTRACT\n\nNuruz Zakiyah, 160271100013. Recru...
# 70  The study was backed by the presence of the in...
# 71  Television is mass media that is often used by...
#
# [72 rows x 6 columns]

# %% [markdown]
# Magister Ilmu Ekonomi

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def magisterekonomi():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 3):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/36/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("magisterekonomi.csv", index=False)

    return df

# %%
magisterekonomi()
# Out:
#                            penulis  \
# 0                          SUMARTO
# 1                         MUSOFFAN
# 2                      Moh. Syarif
# 3              ULY MABRUROH HALIDA
# 4               Sri Rohyatiningsih
# 5              INDHIARSIH SALINDRI
# 6  Lisa Sri rahmatullah, S. Sos. I
# 7               Indah Ainun Nikmah
#
#                                                judul  \
# 0  Analisis Ketaatan Maqashid Syariah\nterhadap P...
# 1  Analisis Daya Dukung Dermaga Branta Pesisir  S...
# 2  ANALISIS PENENTUAN BESARAN DAN PENGELOLAAN DAN...
# 3  PERBANDINGAN PAJAK DAN RETRIBUSI DENGAN ZAKAT ...
# 4  PENGARUH TUNJANGAN KINERJA TERHADAP PRODUKTIVI...
# 5  Pola Mobilitas Komutasi Bagi Pegawai Kontrak d...
# 6  Dampak Sosial Ekonomi Pariwisata Religi Makam ...
# 7  Peranan Zakat Produktif Dalam Meningkatkan Eko...
#
#                    pembimbing_pertama                       pembimbing_kedua  \
# 0               Dr. Sutikno S.E., M.E          Dr. Anita Kristina S.E., M.Si
# 1       Dr. Kurniyati Indahsari, M.Si            Dr. Agus Romadhon, SP. M.Si
# 2              Eni Sri Rahayu Ningsih                          Mohtar Rasyid
# 3             Dr. SUTIKNO, S.E., M.E.           Dr. KURNIYATI INDAHSARI, MSi
# 4       Dr. Mohtar Rasyid, S.E., M.Sc         Dr. Anita Kristina, S.E., M.Si
# 5     Dr. Anita Kristina, S.E., M.Si.         Dr. Mohtar Rasyid, S.E., M.Sc.
# 6  Dr. Diah Wahyuningsih, S.E., M.Si.  Dr. Eni Sri Rahayuningsih, S.E., M.E.
# 7       Dr. Kurniyati Indahsari, M.Si            Dr. Abdur Rahman, S.Ag. MEI
#
#                                         abstrak_indo  \
# 0  Penelitian ini bertujuan untuk menganalisis ba...
# 1  Dermaga  Branta di Desa Branta Pesisir Kecamat...
# 2  Dana Desa adalah dana yang bersumber dari Angg...
# 3  Penelitian ini bertujuan untuk mengetahui perb...
# 4  Seiring dengan adanya tunjangan kinerja bagi p...
# 5  Penelitian ini bertujuan untuk mengungkap feno...
# 6  Penelitian ini bertujuan untuk mengetahui baga...
# 7  Peranan Zakat Produktif dalam Meningkatkan Eko...
#
#                                      abstrak_inggris
# 0  This study aims to analyze how the effects of ...
# 1  Branta Port in Branta Pesisir Tlanakan Pamekas...
# 2  The Village Fund is a funding that sourced fro...
# 3  This study aims to determine the difference be...
# 4  Along with the performance allowance for emplo...
# 5  This study aims to reveal the phenomenon of co...
# 6  The purpose of this study is to analyze the so...
# 7  The Role of Productive Zakat in Improving Must...

# %% [markdown]
# Doktor Ilmu Manajemen

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def doktormanajemen():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 2):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/41/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("doktormanajemen.csv", index=False)

    return df

# %%
doktormanajemen()
# Out:
# Empty DataFrame
# Columns: [penulis, judul, pembimbing_pertama, pembimbing_kedua, abstrak_indo, abstrak_inggris]
# Index: []

# %% [markdown]
# ## Fakultas Teknik

# %% [markdown]
# ### Teknik Industri

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def TI():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 144):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/9/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("TI.csv", index=False)

    return df

# %%
TI()
# Out:
#                               penulis  \
# 0    Siliwangi Fitra Rachmawanto S.T.
# 1                        AHMAD MAS'UD
# 2                   Yulianto Fauzanta
# 3                   M Mundir Muhlisin
# 4                            Muhibbin
# ..                                ...
# 706            YOLANDA ABIGAIL LAPIAN
# 707            Nisfu Laylatus Sabihis
# 708        Muhammad Asri Wahyu Dianto
# 709         MUNIF SAYID ANWAS PRABOWO
# 710            Lilis Kurnia Ikamawati
#
#                                                  judul  \
# 0    OPTIMASI PEMILIHAN PORTOFOLIO SAHAM PERUSAHAAN...
# 1    PERANCANGAN TATA LETAK FASILITAS LANTAI PRODUK...
# 2    PERUMUSAN STRATEGI BISNIS UD. BUDI JAYA BANGKA...
# 3    USULAN PERBAIKAN UTILITAS RESOURCES PADA LANTA...
# 4    Peningkatan Kepuasan Masyarakat Terhadap Pelay...
# ..                                                 ...
# 706  USULAN PERBAIKAN UPAYA MINIMASI REJECT PART BO...
# 707  PERENCANAAN KEBIJAKAN PENGENDALIAN PERSEDIAAN ...
# 708  PENGEMBANGAN DAN KARAKTERISASI HASIL ASSESSMEN...
# 709  Evaluasi Tingkat Kelelahan Kerja Perawat Ruang...
# 710  PENENTUAN TINGKAT PRIORITAS PERBAIKAN MODE KEG...
#
#                                   pembimbing_pertama  \
# 0                    Heri Awalul Ilhamsah S.T., M.T.
# 1                       SABARUDIN AKHMAD, S.T., M.T.
# 2                          Fitri Agustina, S.T., M.T
# 3                                      Mu'alim ST MT
# 4                                     Rahmad Hidayat
# ..                                               ...
# 706   Prof. Dr. Rachmad Hidayat, M.T.,IPU, Asean Eng
# 707                        Sugeng Purwoko, S.T., M.T
# 708  Dr.Sabarudin Akhmad, S.T., M.T., IPM. Asean Eng
# 709                   Dr. Weny Findiastuti, S.T.,M.T
# 710    Dr. Kukuh Winarso, S.Si., M.T, IPM. Asean Eng
#
#                        pembimbing_kedua  \
# 0    Retno Indriartiningtias S.T., M.T.
# 1            SUGENG PURWOKO, S.T., M.T.
# 2    Retno Indriartiningtias, S.T., M.T
# 3                  Sugeng Purwoko ST MT
# 4               Retno Indriartiningtias
# ..                                  ...
# 706            Imron Kuswandi S.T., M.T
# 707                  Mu'alim, S.T., M.T
# 708            Anis Arendra S.T,. M.Eng
# 709             Rullie Annisa, S.T.,M.T
# 710         Issa Dyah Utami, S.T., M.T.
#
#                                           abstrak_indo  \
# 0    Portofolio adalah sekumpulan saham yang dimili...
# 1    PT. ABC merupakan perusahaan yang bergerak dib...
# 2    Bangkalan merupakan salah satu kabupaten yang ...
# 3    Simulasi adalah duplikasi atau abstraksi dari ...
# 4    Kepuasan adalah tingkat perasaan seseorang ter...
# ..                                                 ...
# 706  Kualitas dan pengendalian kualitas memiliki pe...
# 707  PT. Apie Indo Karunia merupakan suatu perusaha...
# 708  MSDs atau Musculoskeletal Disorders adalah gan...
# 709  Rumah sakit merupakan salah satu instansi di b...
# 710  Penelitian ini berlokasikan di PT Semen Indone...
#
#                                        abstrak_inggris
# 0    Portofolio is a collection of stock owned by i...
# 1    PT. ABC is a company engaged in the manufactur...
# 2    Bangkalan is one of the districts that have th...
# 3    Simulation is a duplication or abstraction of ...
# 4    Satisfaction is feeling level of someone to se...
# ..                                                 ...
# 706  Quality and quality control have an important ...
# 707  PT.  Apie Indo Karunia is a company in the man...
# 708  MSDs or Musculoskeletal Disorders are injuries...
# 709  The hospital is one of the institutions in the...
# 710  This research is located at PT Semen Indonesia...
#
# [711 rows x 6 columns]

# %% [markdown]
# ### Teknik Informatika

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def TIF():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 173):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/10/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("TIF.csv", index=False)

    return df

# %%
TIF()
# Out:
#                      penulis  \
# 0         A.Ubaidillah S.Kom
# 1        M. Basith Ardianto,
# 2      Akhmad Suyandi, S.Kom
# 3            Heri Supriyanto
# 4       Septian Rahman Hakim
# ..                       ...
# 853    Rachmad Agung Pambudi
# 854         Nadila Hidayanti
# 855             Afni Sakinah
# 856  Friska Fatmawatiningrum
# 857              Dian Wibowo
#
#                                                  judul  \
# 0    PERANCANGAN DAN IMPLEMENTASI SISTEM DATABASE \...
# 1    APLIKASI KONTROL DAN MONITORING JARINGAN KOMPU...
# 2    RANCANG BANGUN APLIKASI PROXY SERVER UNTUK\r\n...
# 3    SISTEM PENDUKUNG KEPUTUSAN OPTIMASI PENJADWALA...
# 4    SISTEM AUGMENTED REALITY ANIMASI BENDA BERGERA...
# ..                                                 ...
# 853  PENERAPAN ALGORITMA LONG-SHORT TERM MEMORY UNT...
# 854  SISTEM PENCARIAN TEKS AL-QURAN TERJEMAHAN BERB...
# 855  KLASIFIKASI KOMPLEKSITAS VISUAL CITRA SAMPAH M...
# 856  IDENTIFIKASI BINER ATRIBUT PEJALAN KAKI MENGGU...
# 857  DETEKSI OBJEK MANUSIA BERBASIS ONE STAGE DETEC...
#
#                                  pembimbing_pertama  \
# 0                                  Budi Setyono M.T
# 1                             Drs. Budi Soesilo, MT
# 2                            Drs. Budi Soesilo, M.T
# 3                              Mulaab, S.Si., M.Kom
# 4                     Arik Kurniawati, S.Kom., M.T.
# ..                                              ...
# 853            Eka Mala Sari Rochman, S.Kom., M.Kom
# 854                     Achmad Jauhari, S.T., M.Kom
# 855  Dr. Indah Agustien Siradjuddin, S.Kom., M.Kom.
# 856  Dr. Indah Agustien Siradjuddin, S.Kom., M.Kom.
# 857  Dr. Indah Agustien Siradjuddin, S.Kom., M.Kom.
#
#                           pembimbing_kedua  \
# 0                             Hermawan S.T
# 1                            Koko Joni, ST
# 2                         Hermawan, ST, MT
# 3                Firli Irhamni, ST., M.Kom
# 4                     Haryanto, S.T., M.T.
# ..                                     ...
# 853            Sri Herawati, S.Kom., M.Kom
# 854      Ika Oktavia Suzanti, S.Kom., M.Cs
# 855    Moch. Kautsar Sophan, S.Kom., M.MT.
# 856  Prof. Dr. Arief Muntasa, S.Si., M.MT.
# 857    Moch. Kautsar Sophan, S.Kom., M.MT.
#
#                                           abstrak_indo  \
# 0    Sistem  informasi  akademik  (SIAKAD) merupaka...
# 1    Berjalannya koneksi jaringan komputer dengan l...
# 2    Web server adalah sebuah perangkat lunak serve...
# 3    Penjadwalan  kuliah  di  Perguruan  Tinggi  me...
# 4    Seiring perkembangan teknologi yang ada diduni...
# ..                                                 ...
# 853  Investasi saham selama ini memiliki resiko ker...
# 854  Information Retrieval (IR) merupakan pengambil...
# 855  Klasifikasi citra merupakan proses pengelompok...
# 856  Identifikasi atribut pejalan kaki merupakan sa...
# 857  Topik deteksi objek telah menarik perhatian ya...
#
#                                        abstrak_inggris
# 0    Academic information systems (SIAKAD) is an in...
# 1                                                    -
# 2    Web server is a server software functioning to...
# 3    Scheduling  courses  in  universities  is  a  ...
# 4    As the development of technology existing in t...
# ..                                                 ...
# 853  Investment in shares so far has a very large r...
# 854  Information Retrieval (IR) is retrieval of inf...
# 855  Image classification is a process of grouping ...
# 856  The identification of pedestrian attributes is...
# 857  The topic of object detection has attracted gr...
#
# [858 rows x 6 columns]

# %% [markdown]
# ### Manajemen Informatika

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def manajemeninformatika():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 57):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/11/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("manajemeninformatika.csv", index=False)

    return df

# %%
manajemeninformatika()
# Out:
#                               penulis  \
# 0                Elky Lilik Misdayani
# 1                      lu'luul maknun
# 2              Megawati Bukhori Putri
# 3    Andika Syarifuddin Parmana Putra
# 4                  Deka Pranaristanto
# ..                                ...
# 275                   MAKBUL ZAKARIYA
# 276                  Tri Nanda Irawan
# 277                  Satrio Suwantoro
# 278                   Miftahor Rahman
# 279          Moh Ilham Ramdhan Fajrin
#
#                                                  judul  \
# 0    SISTEM INFORMASI PERUSAHAAN OTOBUS SUMBER KENC...
# 1    SISTEM INFORMASI GEOGRAFIS PEMETAAN POTENSI OB...
# 2           SISTEM INFORMASI PSIKOTES BERBASIS DEKSTOP
# 3    Perancangan Dan Pembuatan Sistem Informasi Man...
# 4    SISTEM INFORMASI PEMESANAN RUMAH BERBASIS WEB ...
# ..                                                 ...
# 275  APLIKASI PEMESANAN SIRKUIT LINTASAN BALAP BERB...
# 276  SISTEM MONITORING PENILAIAN KINERJA PEGAWAI\nP...
# 277  Penerapan Metode clustering dengan\n k – means...
# 278  SISTEM INFORMASI GEOGRAFIS PELAYANAN KESEHATAN...
# 279  SISTEM PAKAR DIAGNOSA PENYAKIT MATA DENGAN MEN...
#
#                    pembimbing_pertama               pembimbing_kedua  \
# 0         Fitri Damayanti,S.Kom,M.Kom
# 1                 Aeri Rahmad,S.T,M.T                              -
# 2    Yeni Kustianingsih, S.Kom, M.Kom                              -
# 3                  Sri Herawati,S.Kom             Sri Herawati,S.Kom
# 4          Budi Dwi Satoto S.T, M.Kom     Budi Dwi Satoto S.T, M.Kom
# ..                                ...                            ...
# 275    FITRI DAMAYANTI, S.KOM., M.KOM
# 276      Novi Prastiti, S.Kom., M.Kom
# 277     Novi Prastiti. S.kom,. M.kom.
# 278      Novi Prastiti, S.Kom., M.Kom
# 279     Mohammad Syarief, S.T,. M.Cs.  Mohammad Syarief, S.T,. M.Cs.
#
#                                           abstrak_indo  \
# 0    Sistem informasi pengolahan data yang dibutuhk...
# 1    Abstrak\r\nPerkembangan teknologi di berbagai ...
# 2    Abstrak\r\nPerkembangan teknologi di berbagai ...
# 3    Abstrak\r\n\r\nSistem Informasi Manajemen Data...
# 4    Sistem pemesanan atau profil tentang PT. PROPI...
# ..                                                 ...
# 275  Masyarakat harus datang terlebih dahulu untuk ...
# 276  Pengertian Penilaian kinerja pegawai adalah su...
# 277  Kabupaten Bangkalan merupakan salah satu kabup...
# 278  Pelayanan sebagai proses pemenuhan kebutuhan m...
# 279  ABSTRAK\n\nMata merupakan salah satu dari panc...
#
#                                        abstrak_inggris
# 0    Data processing information systems needed by ...
# 1    Abstract\r\nData processing systems required b...
# 2    Abstract\r\nTechnological developments in vari...
# 3    Abstract\r\n\r\nData Management Information Sy...
# 4    Ordering system or the profile of PT. MAIN WIR...
# ..                                                 ...
# 275  The public must come first to order the race t...
# 276  Understanding Employee appraisal is a structur...
# 277  Bangkalan is one of the districts that have ma...
# 278  Service as a process of fulfilling needs throu...
# 279  ABSTRACT The eye is one of the five senses whi...
#
# [280 rows x 6 columns]

# %% [markdown]
# ### Teknik Multimedia dan Jaringan

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def multimediajaringan():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 28):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/19/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("multimediajaringan.csv", index=False)

    return df

# %%
multimediajaringan()
# Out:
#                          penulis  \
# 0                 Achmad Husaini
# 1          FIKRI MUJADDIDI ALHAK
# 2           artika frida nirmala
# 3                    Ahmad Rivai
# 4                    Idrus Tamam
# ..                           ...
# 126                  Aunur Rofiq
# 127  Rehadian Teja Sukmana Putra
# 128          Ginanjar Eka Poetra
# 129          Rizky wara setyawan
# 130            Muhammad Siswandi
#
#                                                  judul  \
# 0    Elektronik Pemilihan Kepala Desa Menggunakan M...
# 1                        DIGITAL INFORMATION ASSISTANT
# 2    perancangan aplikasi female e-healthy untuk de...
# 3    SISTEM INFORMASI TUGAS AKHIR PRODI TEKNIK MULT...
# 4    APLIKASI PETA WISATA DIGITAL BANGKALAN DENGAN\...
# ..                                                 ...
# 126  APLIKASI SISTEM PENDUKUNG KEPUTUSAN TERHADAP P...
# 127  Sistem Informasi Pangkalan Data Garam di Pulau...
# 128  RANCANG BANGUN SISTEM INFORMASI KEUANGAN  “DEP...
# 129  RANCANG BANGUN APLIKASI DIAGNOSIS PENYAKIT SAP...
# 130  Sistem Pakar Diagnosis Penyakit Unggas Menggun...
#
#                     pembimbing_pertama pembimbing_kedua  \
# 0                Aeri Rachmad, ST. MT.
# 1                AERI RACHMAD, ST., MT
# 2                  Aeri Rachmad ST, MT
# 3               Riza Alfita. S.T.,M.T.                -
# 4              Aeri Rachmad, S.T.,M. T
# ..                                 ...              ...
# 126         M. Ali Syakur, S.Si., M.T.
# 127       Ach. Khozaimi, S.Kom., M.Kom
# 128          M. Ali Syakur, S.Si., M.T
# 129                 Devie Rosa Amanisa
# 130  Devie Rosa Anamisa. S.Kom., M.Kom
#
#                                           abstrak_indo  \
# 0    ABSTRAK\r\n\r\nPerkembangan teknologi informas...
# 1    Media informasi kini perkembangannya sangat pe...
# 2    Kanker serviks merupakan kanker terganas yang ...
# 3    Prodi teknik Multimedia dan Jaringan adalah sa...
# 4    Pemerintah Indonesia telah berupaya meningkatk...
# ..                                                 ...
# 126  Penyakit THT (Telinga Hidung dan Tenggorokan) ...
# 127  Garam merupakan salah satu komoditi besar Indo...
# 128  Proses perkembangan sebuah usaha tidak akan le...
# 129  Peternak sapi  sering mengalami kesulitan dala...
# 130  Unggas adalah jenis hewan  ternak kelompok bur...
#
#                                        abstrak_inggris
# 0    ABSTRACT\r\n\r\nThe development of information...
# 1    Media information is now very rapid developmen...
# 2    Cervical cancer is a vicious cancer caused by ...
# 3    Multimedia and Network engineering is one of t...
# 4    The Indonesian government has worked to increa...
# ..                                                 ...
# 126  ENT disease (Ear Nose and Throat) is a disease...
# 127  Salt is one of Indonesia's major commodities. ...
# 128  The process of development of a business will ...
# 129  Cattle ranchers often have difficulty in findi...
# 130  Poultry is a type of livestock bird group that...
#
# [131 rows x 6 columns]

# %% [markdown]
# ### Mekatronika

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def mekatronika():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 29):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/20/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("mekatronika.csv", index=False)

    return df

# %%
mekatronika()
# Out:
#                      penulis  \
# 0          Moh. Amin Wahyudi
# 1                DWI NUGROHO
# 2        Rezky Septian Akbar
# 3            Rio Tri Susanto
# 4    Moh. Iswahyudinorrahman
# ..                       ...
# 132        Agus Dian Prayana
# 133          Rifki Masfuddin
# 134                  Yudiono
# 135  Jundullah Abdul Aziz M.
# 136      Satria Jaya Rizaldy
#
#                                                  judul  \
# 0    PERANCANGAN INJECTOR CLEANER DAN TESTER PADA S...
# 1    PROTOTYPE ALAT PEMBERI PAKAN\r\nAYAM PETELUR O...
# 2               pengukur tinggi badan berbasis arduino
# 3    PEMODELAN SISTEM INFORMASI KETERSEDIAAN RUANG ...
# 4    Desain Sistem pengendali Pintu otomatis Menggu...
# ..                                                 ...
# 132                     JAM BERBICARA UNTUK TUNA NETRA
# 133  Alat daur ulang kertas menjadi bubur kertas (p...
# 134  Alat Penyiram Bawang Merah Otomatis Untuk Meng...
# 135  PROTOTIPE KONVEYOR BERBASIS METAL DETEKSI MAGN...
# 136                     PROTOTYPE PEMERIKSA BUTA WARNA
#
#                       pembimbing_pertama              pembimbing_kedua  \
# 0             Hairil Budiarto, S.T., MT.
# 1            Muhammad Fuad, S.Kom. , MT.  Mirza Pramudia, ST. , M.Eng.
# 2     Ahmad Sahru Romadhon, S.Kom., M.T.
# 3              Muhammad Latif, S.T., M.T
# 4     ahmad Sahru Romadhon, S.KOM., M.T.
# ..                                   ...                           ...
# 132                SRI WAHYUNI,S.KOM.M.T
# 133  Vivi Tri Widyaningrum, S.Kom., M.T.
# 134             Sri Wahyuni, S.Kom, M.T.
# 135             Sri Wahyuni, S.Kom., M.T
# 136          Hairil Budiarto., S.T., M.T
#
#                                           abstrak_indo  \
# 0    ABSTRAK\r\nSepeda motor menggunakan sistem inj...
# 1    Peternakan merupakan salah satu bidang usaha y...
# 2    Perkembangan ilmu pengetahuan teknologi yang m...
# 3    Pengaturan parkir yang sampai saat ini masih b...
# 4    Pada zaman globalisasi mendorong teknologi unt...
# ..                                                 ...
# 132  Indera penglihatan adalah salah satu sumber in...
# 133  Daur ulang limbah kertas adalah proses untuk m...
# 134  Bawang merah merupakan sayuran rempah yang cuk...
# 135  Keunggulan dalam bidang teknologi di era moder...
# 136  ABSTRAK\n\nPenelitian ini bertujuan untuk memb...
#
#                                        abstrak_inggris
# 0    ABSTRACT\r\nMotorcycle injection system is cur...
# 1    Livestock is one of the promising areas of bus...
# 2    The development of modern technology science h...
# 3    Mostly parking arrangement was done manually u...
# 4    At globalization epoch push technology to rapi...
# ..                                                 ...
# 132  The senses of detection are one of the main in...
# 133  Waste paper recycling is a process to utilize ...
# 134  Shallots are spice vegetables that are quite p...
# 135  Excellence in the field of technology in the m...
# 136  ABSTRACT\n\nThis study aims to build a color b...
#
# [137 rows x 6 columns]

# %% [markdown]
# ### Teknik Elektro

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def elektro():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 35):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/23/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("elektro.csv", index=False)

    return df

# %%
elektro()
# Out:
#                          penulis  \
# 0                   Achmad Faidi
# 1             Dandi Fathur Rohim
# 2    Reynanda Bagus Widyo Astomo
# 3    Moh.Nazilus Sa’din Romdloni
# 4             Fajar Dwima Wijaya
# ..                           ...
# 162         Prayogo Teguh Wibowo
# 163           KHOLIFATUL SADHIAH
# 164          Tantra Juang Ilhami
# 165             ACHMAD NUR RIVAI
# 166         Noer Indra Afriansya
#
#                                                  judul  \
# 0    RANCANG BANGUN PENGATUR TEGANGAN OTOMATIS PADA...
# 1            SMART GARBAGE BERBASIS INTERNET OF THINGS
# 2    Perancangan dan Pembuatan Stop Kontak Berbasis...
# 3    PROTOTYPE SISTEM MONITORING DAN PENGENDALIAN P...
# 4    Rancang Bangun Sistem Keamanan Parkir Berbasis...
# ..                                                 ...
# 162  Implementasi Convolutional Neural Network Untu...
# 163  OPTIMALISASI KINERJA PSTN KE VOIP DENGAN MIGRA...
# 164  MONITORING BAHAN BAKAR GENERATOR DENGAN MENGGU...
# 165  RANCANGAN SISTEM MOBILE ROBOT SOUND LOCALIZATI...
# 166  APLIKASI PENGENALAN INFORMASI OBJEK BERSEJARAH...
#
#                 pembimbing_pertama                     pembimbing_kedua  \
# 0          Koko Joni. S.T., M.Eng.  Achmad Fiqhi Ibadillah, S.T., M.Sc.
# 1              Haryanto. S.T., M.T               Koko Joni. S.T., M.Eng
# 2
# 3                  Haryanto,ST,.MT                   Riza Alfita,ST,.MT
# 4       Diana Rahmawati, S.T., M.T        Kunto Aji Wibisono, S.T., M.T
# ..                             ...                                  ...
# 162         Koko Joni, S.T., M.Eng    Achmad Fiqi Ibadillah, S.T., M.Sc
# 163  Ahmad Ubaidillah Ms.,S.T.,MT.                 Haryanto, S.T., M.T.
# 164         Miftachul Ulum ST,.MT.              Riza Alfita, S.T., M.T.
# 165       DIANA RAHMAWATI,ST.,M.T.     ACHMAD FIQHI IBADILLAH,S.T.,M.Sc
# 166     Miftachul Ulum, S.T., M.T.              Riza Alfita, S.T., M.T.
#
#                                           abstrak_indo  \
# 0    Tegangan yang tidak stabil dapat merusak peran...
# 1    Sampah di Indonesia merupakan suatu masalah ya...
# 2    Pengunaan perangkat elektris dalam kehidupan s...
# 3    Indonesia merupakan negara dengan curah hujan ...
# 4    Sistem pengelolaan tempat parkir pada saat ini...
# ..                                                 ...
# 162  Informasi teks merupakan salah satu komponen p...
# 163  Public Switched Telephone Network (PSTN) adala...
# 164  Pemakaian energi listrik semakin lama semakin ...
# 165  Sistem kontrol robot beroda pada umumnya berbe...
# 166  Museum Keraton Sumenep merupakan salah satu de...
#
#                                        abstrak_inggris
# 0    Unstable voltages can damage electronic device...
# 1    Trash is one of serious prroblems in Indonesi....
# 2    The use of electrical devices in everyday life...
# 3    Indonesia known as the country with heavy rain...
# 4    Parking management system at this time is stil...
# ..                                                 ...
# 162
# 163  Public Switched Telephone Network (PSTN) is a ...
# 164  The use of electricity is increasing as all jo...
# 165  Wheeled robot control systems generally take t...
# 166  Sumenep Palace Museum is a destination that is...
#
# [167 rows x 6 columns]

# %% [markdown]
# ### Sistem Informasi

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def sisfor():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 2):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/31/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("sisfor.csv", index=False)

    return df

# %%
sisfor()
# Out:
# Empty DataFrame
# Columns: [penulis, judul, pembimbing_pertama, pembimbing_kedua, abstrak_indo, abstrak_inggris]
# Index: []

# %% [markdown]
# ### Teknik Mesin

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def mesin():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 2):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/32/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("mesin.csv", index=False)

    return df

# %%
mesin()
# Out:
# Empty DataFrame
# Columns: [penulis, judul, pembimbing_pertama, pembimbing_kedua, abstrak_indo, abstrak_inggris]
# Index: []

# %% [markdown]
# ### Teknik Mekatronika

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def teknikmekatro():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 4):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/33/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("teknikmekatro.csv", index=False)

    return df

# %%
teknikmekatro()
# Out:
#                         penulis  \
# 0         Mochamad Izar Bahroni
# 1                    Moch Zaini
# 2           Mohammad Syafruddin
# 3    Khanif Khoirul Umam, A.Md.
# 4          Achmad Ayubal Ansori
# 5               Raudatul Jannah
# 6                    Ach. Dafid
# 7                     MOH HOLIL
# 8             Ach Imam Sudianto
# 9            MOH TAUFIK HIDAYAT
# 10          Alvian Ainun Fajrih
# 11  ADINDA DEBTIANA DWIKA HILDA
# 12            Nafizatul Jamilah
# 13                   Agus Salim
#
#                                                 judul  \
# 0   Kestabilan Autonomous Quadcopter Dengan Kontro...
# 1   perancangan dan pembuatan sistem rem elektrik ...
# 2   Pengatur Kerapatan Kertas Pada Alat Penggulung...
# 3   IMPLEMENTASI ALGORITMA MAZE MAPPING PENCARIAN ...
# 4   Alat Pengering Rumput Laut Menggunakan Metode ...
# 5   ROBOT PENDETEKSI LOKASI KEBOCORAN PADA PIPA LI...
# 6   SISTEM KENDALI KADAR Ph DAN TEMPERATUR TAMBAK ...
# 7   PERANCANGAN PROTOTIPE ALAT PENUKAR \nPANAS MEN...
# 8   PEMANFAATAN ANTI-ROLL TERHADAP KESEIMBANGAN KAPAL
# 9   ALAT PENGGULUNG UNTUK MENGATUR KERAPATAN KERTA...
# 10    Optimasi Penguapan Air Laut Tua Pada Rumah Kaca
# 11  KESTABILAN KECEPATAN MOBILE ROBOT PADA LINTASA...
# 12  Rancang Bangun Sistem Otomasi Robot Pengecatan...
# 13  Sistem Kestabilan Gerak Robot Omnidirection Me...
#
#                     pembimbing_pertama                     pembimbing_kedua  \
# 0             Sri Wahyuni, S.Kom., M.T             Faikul Umam, S.Kom., M.T
# 1              Hairil Budiarto., ST.MT              Faikul Umam., S.Kom.,MT
# 2              Faikul Umam S.Kom., M.T     Ahmad Sahru Romadhon S.Kom., M.T
# 3            Sri Wahyuni, S.Kom., M.T.           Hairil Budiarto, S.T.,M.T.
# 4            Ahmad Sahru R.,S.Kom.,M.T             Hairil Budiarto S.T.,M.T
# 5              Vivi Tri .W, S.Kom.,MT.              Hairil Budiarto,ST.,MT.
# 6   Vivi Tri Widyaningrum, S.Kom.,M.T.            Hairil Budiarto,S.T.,M.T.
# 7       AHMAD SAHRU ROMADHON.,S.Kom.MT               HAIRIL BUDIARTO.,ST.MT
# 8            Hairil Budiarto S.T., M.T  Vivi Tri Widyanningrum S.Kom., M.T.
# 9            FAIKUL UMAM., S.KOM., M.T            SRI WAHYUNI., S.KOM., M.T
# 10         Hairil Budiarto, S.T., M.T.            Faikul Umam, S.Kom., M.T.
# 11           Faikul Umam, S.Kom., M.T.            Sri Wahyuni, S.Kom., M.T.
# 12          Hairil Budiarto, S.T., M.T             Sri Wahyuni, S.Kom., M.T
# 13             Vivi Tri W, S.Kom., M.T           Ahmad Sahru R, S.Kom., M.T
#
#                                          abstrak_indo  \
# 0   Unmanned Aerial Vehicle (UAV) memiliki banyak ...
# 1   Kendaraan merupakan suatu alat yang banyak dig...
# 2   PT PAKERIN adalah salah satu pabrik kertas ter...
# 3   Robot shortest path merupakan jenis robot yang...
# 4   Rumput laut merupakan tumbuhan laut yang banya...
# 5   LPG adalah singkatan dari Liquefied Petroleum ...
# 6   Komoditas hewan air yang mampu mengahasilkan d...
# 7   Perancangan Prototype alat ini dilakukan karen...
# 8   Kapal adalah alat transportasi pengangkut penu...
# 9   ABSTRAK\n\nKertas merupakan kebutuhan yang dib...
# 10  Pembuatan garam di Madura umumnya dilakukan de...
# 11  Mobile robot merupakan salah satu kategori rob...
# 12  ABSTRAK\n\nMarka jalan raya adalah sebuah tand...
# 13  Di era globalisasi ini sangatlah mungkin tekno...
#
#                                       abstrak_inggris
# 0   Unmanned Aerial Vehicle (UAV) has many uses, i...
# 1   Vehicle is a tool that is widely used by human...
# 2   PT PAKERIN is one of the largest paper mills i...
# 3   Shortest path robot is a type of robot that is...
# 4   Seaweed is a marine plant widely cultivated by...
# 5   LPG stands for Liquefied Petroleum Gas which m...
# 6   Animal water commodities capable of producing ...
# 7   Prototype design tool is done because the medi...
# 8   The ship is a means of transporting passengers...
# 9   ABSTRACT\n\nPaper is a necessity needed by hum...
# 10  Making salt in Madura is generally done by hea...
# 11  Mobile robot is one of the robot categories th...
# 12  ABSTRACT\n\nA highway mark is a sign that can ...
# 13  In this globalization era, it is very possible...

# %% [markdown]
# ## Ilmu Sosial Dan Ilmu Budaya

# %% [markdown]
# ### Sosiologi

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def sosiologi():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 137):
        print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/12/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("sosiologi.csv", index=False)

    return df

# %%
sosiologi()
# Out:
# 📄 Memproses halaman ke-1
# 📄 Memproses halaman ke-2
# 📄 Memproses halaman ke-3
# 📄 Memproses halaman ke-4
# 📄 Memproses halaman ke-5
# 📄 Memproses halaman ke-6
# 📄 Memproses halaman ke-7
# 📄 Memproses halaman ke-8
# 📄 Memproses halaman ke-9
# 📄 Memproses halaman ke-10
# 📄 Memproses halaman ke-11
# 📄 Memproses halaman ke-12
# 📄 Memproses halaman ke-13
# 📄 Memproses halaman ke-14
# 📄 Memproses halaman ke-15
# 📄 Memproses halaman ke-16
# 📄 Memproses halaman ke-17
# 📄 Memproses halaman ke-18
# 📄 Memproses halaman ke-19
# 📄 Memproses halaman ke-20
# 📄 Memproses halaman ke-21
# 📄 Memproses halaman ke-22
# 📄 Memproses halaman ke-23
# 📄 Memproses halaman ke-24
# 📄 Memproses halaman ke-25
# 📄 Memproses halaman ke-26
# 📄 Memproses halaman ke-27
# 📄 Memproses halaman ke-28
# 📄 Memproses halaman ke-29
# 📄 Memproses halaman ke-30
# 📄 Memproses halaman ke-31
# 📄 Memproses halaman ke-32
# 📄 Memproses halaman ke-33
# 📄 Memproses halaman ke-34
# 📄 Memproses halaman ke-35
# 📄 Memproses halaman ke-36
# 📄 Memproses halaman ke-37
# 📄 Memproses halaman ke-38
# 📄 Memproses halaman ke-39
# 📄 Memproses halaman ke-40
# 📄 Memproses halaman ke-41
# 📄 Memproses halaman ke-42
# 📄 Memproses halaman ke-43
# 📄 Memproses halaman ke-44
# 📄 Memproses halaman ke-45
# 📄 Memproses halaman ke-46
# 📄 Memproses halaman ke-47
# 📄 Memproses halaman ke-48
# 📄 Memproses halaman ke-49
# 📄 Memproses halaman ke-50
# 📄 Memproses halaman ke-51
# 📄 Memproses halaman ke-52
# 📄 Memproses halaman ke-53
# 📄 Memproses halaman ke-54
# 📄 Memproses halaman ke-55
# 📄 Memproses halaman ke-56
# 📄 Memproses halaman ke-57
# 📄 Memproses halaman ke-58
# 📄 Memproses halaman ke-59
# 📄 Memproses halaman ke-60
# 📄 Memproses halaman ke-61
# 📄 Memproses halaman ke-62
# 📄 Memproses halaman ke-63
# 📄 Memproses halaman ke-64
# 📄 Memproses halaman ke-65
# 📄 Memproses halaman ke-66
# 📄 Memproses halaman ke-67
# 📄 Memproses halaman ke-68
# 📄 Memproses halaman ke-69
# 📄 Memproses halaman ke-70
# 📄 Memproses halaman ke-71
# 📄 Memproses halaman ke-72
# 📄 Memproses halaman ke-73
# 📄 Memproses halaman ke-74
# 📄 Memproses halaman ke-75
# 📄 Memproses halaman ke-76
# 📄 Memproses halaman ke-77
# 📄 Memproses halaman ke-78
# 📄 Memproses halaman ke-79
# 📄 Memproses halaman ke-80
# 📄 Memproses halaman ke-81
# 📄 Memproses halaman ke-82
# 📄 Memproses halaman ke-83
# 📄 Memproses halaman ke-84
# 📄 Memproses halaman ke-85
# 📄 Memproses halaman ke-86
# 📄 Memproses halaman ke-87
# 📄 Memproses halaman ke-88
# 📄 Memproses halaman ke-89
# 📄 Memproses halaman ke-90
# 📄 Memproses halaman ke-91
# 📄 Memproses halaman ke-92
# 📄 Memproses halaman ke-93
# 📄 Memproses halaman ke-94
# 📄 Memproses halaman ke-95
# 📄 Memproses halaman ke-96
# 📄 Memproses halaman ke-97
# 📄 Memproses halaman ke-98
# 📄 Memproses halaman ke-99
# 📄 Memproses halaman ke-100
# 📄 Memproses halaman ke-101
# 📄 Memproses halaman ke-102
# 📄 Memproses halaman ke-103
# 📄 Memproses halaman ke-104
# 📄 Memproses halaman ke-105
# 📄 Memproses halaman ke-106
# 📄 Memproses halaman ke-107
# 📄 Memproses halaman ke-108
# 📄 Memproses halaman ke-109
# 📄 Memproses halaman ke-110
# 📄 Memproses halaman ke-111
# 📄 Memproses halaman ke-112
# 📄 Memproses halaman ke-113
# 📄 Memproses halaman ke-114
# 📄 Memproses halaman ke-115
# 📄 Memproses halaman ke-116
# 📄 Memproses halaman ke-117
# 📄 Memproses halaman ke-118
# 📄 Memproses halaman ke-119
# 📄 Memproses halaman ke-120
# 📄 Memproses halaman ke-121
# 📄 Memproses halaman ke-122
# 📄 Memproses halaman ke-123
# 📄 Memproses halaman ke-124
# 📄 Memproses halaman ke-125
# 📄 Memproses halaman ke-126
# 📄 Memproses halaman ke-127
# 📄 Memproses halaman ke-128
# 📄 Memproses halaman ke-129
# 📄 Memproses halaman ke-130
# 📄 Memproses halaman ke-131
# 📄 Memproses halaman ke-132
# 📄 Memproses halaman ke-133
# 📄 Memproses halaman ke-134
# 📄 Memproses halaman ke-135
# 📄 Memproses halaman ke-136
#                       penulis  \
# 0            Arief Barawijaya
# 1                       sabri
# 2         syarif hidayatullah
# 3                       Rusli
# 4                      MAHMUD
# ..                        ...
# 672         Alfiah Nur Rohmah
# 673  Ayu Aprilia Puji Lestari
# 674     mohammad sa'nun fauzi
# 675       Citra Zelyn Pratiwi
# 676        RIAN PANDI PRANATA
#
#                                                  judul  \
# 0    STRATEGI ADAPTASI PEDAGANG MAKANAN TRADISIONAL...
# 1    TRADISI PERTUNANGAN PADA USIA DINI\r\n( Studi ...
# 2    DINAMIKA PERSAINGAN PERAN KIAI DAN BLATER DALA...
# 3    FENOMENA JUDI MELALUI MIG33\r\nPADA MASYARAKAT...
# 4    Konstruksi Sosial Predikat Haji (Studi Kasus D...
# ..                                                 ...
# 672  Makna Bhubuhan Sebagai Bentuk Pelunasan Hutang...
# 673  STRATEGI PENGUATAN KEPERCAYAAN\n( Studi Pada P...
# 674  BENTUK PERLAWANAN MASYARAKAT TERHADAP GALIAN C...
# 675  Strategi Bertahan Hidup Buruh Tani Wanita Dala...
# 676  Analisis Wacana Media Online Detik.com dalam M...
#
#                                     pembimbing_pertama  \
# 0                                   Drs. Subandri, M.S
# 1                                  Drs. Subandri., M.S
# 2                        syamsu budiyanti, S.sos, M.si
# 3                        Syamsu budiyanti, S.Sos. M.Si
# 4                                   Drs. Subandri, M.S
# ..                                                 ...
# 672               Dr. Arie Wahyu Prananta, S.Pi, M.Sos
# 673  Bangun Sentosa Dwi Haryanto., S.Sos., M.Si., Ph.D
# 674                  Khoirul Rosyadi, SS., M.Si., Ph.D
# 675               Dr. Arie Wahyu Prananta, S.Pi,.M.sos
# 676             Dr. Arie Wahyu Prananta, S.Pi.,M.Sos.,
#
#                         pembimbing_kedua  \
# 0      Arie Wahyu Prananta, S.Pi., M.Sos
# 1               Dr. Sri Hidayati., M.Si.
# 2      iskandar dzulkarnain, S.Thi, M.si
# 3               Arie Wahyu P. S.Pi. M.Si
# 4    Iskandar Dzulkarnain, S.Th.I., M.Si
# ..                                   ...
# 672
# 673
# 674
# 675
# 676
#
#                                           abstrak_indo  \
# 0    RINGKASAN\r\nArief Barawijaya, NIM. 08.05.2.1....
# 1    ABSTRAK\r\nPenelitian ini berjudul “Tradisi Pe...
# 2    ABSTRAK\r\nSyarif Hidayatullah NIM. 07.01.211....
# 3    FENOMENA JUDI MELALUI MIG33 \r\nPADA MASYARAKA...
# 4    ABSTRAK\r\nMahmud, NIM. 08.05.2.1.2.000.02, Pr...
# ..                                                 ...
# 672  Tujuan dari penelitian ini adalah untuk menget...
# 673  Abstrak - Ayu Aprilia Puji Lestari, NIM 160521...
# 674  Tujuan dari penelitian ini adalah untuk mengam...
# 675  ABSTRAK \nTujuan dari penelitian ini yaitu unt...
# 676  Abstrak\n\n Rian Pandi Pranata. NIM 1605211000...
#
#                                        abstrak_inggris
# 0    ABSTRACT\r\n\r\n\r\nBarawijaya, Arief. NIM. 08...
# 1    ABSTRACT\r\n\tThe research entitle "Engagement...
# 2    ABSTRACT \r\nSyarif Hidayatullah NIM 07.01.211...
# 3    ABSTRACT\r\nSociology Studies Program, Faculty...
# 4    ABSTRACT\r\nMahmud, NIM. 08.05.2.1.2.000.02, S...
# ..                                                 ...
# 672  The purpose of this study is to find out how t...
# 673  Abstract - Ayu Aprilia Puji Lestari, NIM 16052...
# 674  The purpose of this study is to describe and e...
# 675  ABSTRACK \nThe purpose of this study is to fin...
# 676  ABSTRACT\n\n Rian Pandi Pranata. NIM 160521100...
#
# [677 rows x 6 columns]

# %% [markdown]
# ### Ilmu Komunikasi

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def ilkom():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 136):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/13/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("ilkom.csv", index=False)

    return df

# %%
ilkom()
# Out:
#                           penulis  \
# 0                  MUHAMMAD MOHED
# 1           Lely Faizatun Masfufa
# 2                    AGUS PRAMONO
# 3    Delfriska Novawati Panjaitan
# 4       Bravo Jaya Pramono Sinaga
# ..                            ...
# 669                Aini Wulandari
# 670                  Riski Hakiki
# 671             RINDA DWI PRADINA
# 672                    Ayu Fitria
# 673         Rina Astaria Mendrova
#
#                                                  judul  \
# 0    STRATEGI KOMUNIKASI PEMASARAN KOPERASI SIMPAN ...
# 1    Pengaruh Terpaan Iklan Hilo Teen Versi Dance t...
# 2    “MAKNA, TRADISI DAN SIMBOL DALAM UPACARA ROKAT...
# 3    REPRESENTASI NILAI-NILAI BUDAYA LOKAL KOREA ME...
# 4    KONSTRUKSI TRADISI MUSLIM SURABAYA MELALUI ISI...
# ..                                                 ...
# 669  Komunikasi Antar Blater dalam Tradisi Remoh se...
# 670  Bias Gender Jurnalis Perempuan Di Media Massa ...
# 671  SUPPORTIVENESS SINGLE FATHER DALAM MEMBANGUN H...
# 672  KOMUNIKASI PEMASARAN WISATA BUKIT JADDIH BANGK...
# 673  Fenomenologi Relawan Kelompok Dukungan Sebaya ...
#
#                           pembimbing_pertama  \
# 0    Netty Dyah Kurniasari, S.Sos, M.Med.Kom
# 1              Nikmah Suryandari,S.Sos, M.Si
# 2         DINARA MAYA JULIJANTI, S.Sos, M.Si
# 3            Netty Dyah K, S.Sos., M.Med.Kom
# 4                     Surokim, S.Sos., M.Si.
# ..                                       ...
# 669   Dr. Bani Eka Dartiningsih, S.Sos., MSi
# 670     Dr. Yuliana Rakhmawati, S.Sos., M.Si
# 671      Dr.Yuliana Rakhmawati, S.Sos.,M.Si.
# 672     R. Bambang Moertijoso, S,Sos., M.Si.
# 673    Dr. Yuliana Rakhmawati, S.Sos., M.Si.
#
#                          pembimbing_kedua  \
# 0               Muhtar Wahyudi, S.Sos, MA
# 1       Dinara Maya Julijanti,S.Sos, M.Si
# 2              TATAQ HANDAKA, S.Sos, M.Si
# 3            Dewi Quraisyin, S.Pdi., M.Si
# 4       Dessy Trisilowaty, S.Sos., M. Si.
# ..                                    ...
# 669  Dr. Yuliana Rakhmawati, S.Sos., M.Si
# 670
# 671                                     -
# 672            Imam Sofyan, S.Sos., M.Si.
# 673                                     -
#
#                                           abstrak_indo  \
# 0    ABSTRAKSI\r\n\r\nSTRATEGI KOMUNIKASI PEMASARAN...
# 1    ABSTRACT\r\nState Senior High School 1 Surabay...
# 2    ABSTRAK\r\nAgus Pramono, NIM. 08.05.3.1.1.000....
# 3    REPRESENTASI NILAI-NILAI BUDAYA LOKAL KOREA ME...
# 4    TV9 Surabaya adalah media massa milik NU yang ...
# ..                                                 ...
# 669  ABSTRAK\n\nRemoh blater diadakan untuk berkump...
# 670  Penelitian ini berjudul Bias Gender Jurnalis P...
# 671  ABSTRAK\nRinda Dwi Pradina 160531100026, Progr...
# 672  ABSTRAK\n\nTujuan utama dari penelitian ini ad...
# 673  Abstrak - Tujuan dari penelitian ini adalah me...
#
#                                        abstrak_inggris
# 0    ABSTRACT  \r\n\r\nMARKETING COMMUNICATION STRA...
# 1    ABSTRAK\r\nSMA  Negeri  1  Surabaya adalah  sa...
# 2    ABSTRACT\r\nAgus Pramono, NIM.  08. 05.3.1.1. ...
# 3    REPRESENTATION THE VALUES OF KOREAN CULTURE FR...
# 4    TV9 Surabaya is mass media own the NU presenti...
# ..                                                 ...
# 669  ABSTRACT\n\nThe Remoh of the blater was held f...
# 670  This research is titled Gender bias of Women j...
# 671  ABSTRACT\nRinda Dwi Pradina 160531100026, Comm...
# 672  ABSTRACT\n\nThe main purpose of this research ...
# 673  Abstract - The purpose of this study is to fin...
#
# [674 rows x 6 columns]

# %% [markdown]
# ### Psikologi

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def psikologi():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 105):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/14/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("psikologi.csv", index=False)

    return df

# %%
psikologi()
# Out:
#                      penulis  \
# 0              Badrus Syamsi
# 1               Umarul Faruk
# 2             TONI TRIATMOKO
# 3                      ROKIP
# 4          JUJUK EKO WAHYUDI
# ..                       ...
# 512  Crusita Widya Anggraeni
# 513      ALIFIYA RIZKI LAILY
# 514    SEPTIANA CAHYANINGRUM
# 515        ISROH DWI NURLITA
# 516           Siti Komariyah
#
#                                                  judul  \
# 0    Pengaruh Kompetensi Profesional Guru terhadap ...
# 1    Perbedaan Tingkat Kemandirian dan Prestasi Bel...
# 2    Pengaruh Kecerdasan Emosional terhadap Culture...
# 3    RISK-TAKING BEHAVIORS KAUM ELITE BLATER\r\nDI ...
# 4    Etos Kerja Tukang Rawat Sapi Karapan Madura (S...
# ..                                                 ...
# 512  SELF COMPASSION PADA SURVIVOR HIV-AIDS DENGAN ...
# 513  HUBUNGAN ANTARA PROKRASTINASI AKADEMIK DENGAN ...
# 514  INTIMACY AYAH (SINGLE PARENT) TERHADAP ANAK PE...
# 515  HUBUNGAN NILAI SOSIAL DENGAN PERILAKU ALTRUISM...
# 516  Perbedaan Kebahagaiaan Pasangan Pernikahan Per...
#
#                               pembimbing_pertama  \
# 0               Alifah Rahma Wati. S.Psi., M.Psi
# 1                    Zainal Abidin. S.Psi., M.Si
# 2                     HERA WAHYUNI, M.Psi., Psi.
# 3                       Yan Ariyani, M.Psi., Psi
# 4               Yan Ariyani S.Psi., M.Psi., Psi.
# ..                                           ...
# 512   Alifah Rahma Wati S.Psi., M.Psi., Psikolog
# 513  Fandi Rosi Sarwo Edi, S.K.M., S.Psi., M.Psi
# 514      YAN ARIYANI, S. PSI., M. PSI., PSIKOLOG
# 515  FANDI ROSI SARWO EDI, S.K.M., S.Psi., M.Psi
# 516                 Dr. Netty Herawati. Psikolog
#
#                          pembimbing_kedua  \
# 0             Zainal Abidin. S.Psi., M.Si
# 1           Nur Aziz Afandi. S.Psi., M.Si
# 2            ZAINAL ABIDIN, S.Psi., M.Si.
# 3           Alifah Rahma Wati, M.Psi.,Psi
# 4    Alifah Rahma Wati S.Psi, M.Psi, Psi.
# ..                                    ...
# 512
# 513
# 514
# 515
# 516
#
#                                           abstrak_indo  \
# 0    Guru yang berkualitas, berkompetensi profesion...
# 1    Kemandirian merupakan salah satu faktor penduk...
# 2    Penelitian ini bertujuan untuk mengetahui adan...
# 3    Penelitian ini bertujuan untuk mendeskripsikan...
# 4    Penelitian ini bertujuan untuk mengetahui Etos...
# ..                                                 ...
# 512  Penelitian ini bertujuan mengetahui self compa...
# 513  Penelitian ini bertujuan untuk mengetahui hubu...
# 514  ABSTRAK\nPenelitian ini bertujuan untuk menget...
# 515  Mayarakat relawan Indonesia (MRI) Surabaya ter...
# 516  Siti Komariyah. 130541100133. Perbedaan kebaha...
#
#                                        abstrak_inggris
# 0    Qualified teachers, professional competence, w...
# 1    Independence is one of the contributing factor...
# 2    This study aims to understand the influence of...
# 3    This study aims to understand the description ...
# 4    This study aimed to determine the working etho...
# ..                                                 ...
# 512  This study aims to determine the self-compassi...
# 513  This study aims to determine the relationship ...
# 514  ABSTRACT\nThis study aims to describe intimacy...
# 515  The Indonesian volunteer society (MRI) Surabay...
# 516  Siti Komariyah. 130541100131. The difference b...
#
# [517 rows x 6 columns]

# %% [markdown]
# ### Sastra Inggris

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def sasing():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 134):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/15/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("sasing.csv", index=False)

    return df

# %%
sasing()
# Out:
#                  penulis                                              judul  \
# 0                a'isyah     A Study of Language Variety on Facebook Status
# 1            Atik Husnia  A study of Conjunction Translation in the nove...
# 2        Mochammad Hanif  The Universal Narrative Structure in John Stei...
# 3         Deny Andrianto  A Study of Conversational Implicature Uttered ...
# 4            Tri Maryono  Lady Macbeth's Somnambulism in Shakespeare's M...
# ..                   ...                                                ...
# 660  Dewi Retno Indawati  Multimodal Analysis of Promotional Video in Lo...
# 661    Meliya Intan Sari  CHARACTER AND PLOT DEVELOPMENT IN ALICE MUNRO’...
# 662  Dyanatul Mustaqimah  An Acoustic Analysis of English Vowels Produce...
# 663     NAFILATUN NASUHA  AN ANALYSIS OF PERSONAL PRONOUNS IN DONALD TRU...
# 664         Sulfi Amalia  AN ANALYSIS OF CATEGORY SHIFT IN THE ENGLISH T...
#
#                     pembimbing_pertama                   pembimbing_kedua  \
# 0        Iqbal Nurul Azhar, SS.,M.Hum.          Diah Ikawati A.,SS.,M.Pd.
# 1                   Sriyono, SS.,M.Hum             Rosyida Ekawati, SS.MA
# 2      Imron Wakhid Harits, SS., M.Pd.            Rifah Inayati, SS., MA.
# 3                  Sriyono, SS., M.Hum      Iqbal Nurul Azhar, SS., M.Hum
# 4                Dr. Suryo Tri Saksono           Suci Suryani, S.S., M.Pd
# ..                                 ...                                ...
# 660     Dr. Rosyida Ekawati, S.S., M.A
# 661  Zakiyatul Mufidah, S.Hum., M.Hum.  Zakiyatul Mufidah, S.Hum., M.Hum.
# 662         Misnadin, S.S., M.A., Ph.D
# 663     Dr. Rosyida Ekawati, S.S., M.A
# 664                  Dr. Masduki, M.Pd
#
#                                           abstrak_indo  \
# 0    ABSTRACT\r\n\r\nAisyah. 08.05.111.00018. A Stu...
# 1    ABSTRACT\r\n\r\nHusnia, Atik. 08.05.111.00017....
# 2
# 3    ABSTRACT\r\n\r\nAndrianto, Deny. 08.05.111.000...
# 4
# ..                                                 ...
# 660  Penelitian ini bertujuan untuk meneliti tentan...
# 661  ABSTRAK\n\nSari, Meliya Intan. 13.05.111.00068...
# 662
# 663  ABSTRACT\n\nNafilatun Nasuha. 160511100005. An...
# 664  Sulfi Amalia. 15.05.111.00021. English Study P...
#
#                                        abstrak_inggris
# 0    ABSTRACT\r\n\r\nAisyah. 08.05.111.00018. A Stu...
# 1    ABSTRACT\r\n\r\nHusnia, Atik. 08.05.111.00017....
# 2    ABSTRACT\r\n\r\nHanif, Mochammad. 08.05.111.00...
# 3    ABSTRACT\r\n\r\nAndrianto, Deny. 08.05.111.000...
# 4    ABSTRACT\r\n\r\nMaryono, Tri. 06.05.1.1.1.0000...
# ..                                                 ...
# 660  The study aimed to explain the representation ...
# 661  ABSTRACT\n\nSari, Meliya Intan. 13.05.111.0006...
# 662  This study focused on the English vowels [æ], ...
# 663  ABSTRACT\n\nNafilatun Nasuha. 160511100005. An...
# 664  Sulfi Amalia. 15.05.111.00021. English Study P...
#
# [665 rows x 6 columns]

# %% [markdown]
# ## Keislaman

# %% [markdown]
# ### Ekonomi Syariah

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def ekosyariah():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 114):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/16/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("ekosyariah.csv", index=False)

    return df

# %%
ekosyariah()
# Out:
#                          penulis  \
# 0              MOH. MUHLIS ANWAR
# 1                         Fatima
# 2                VIVID NUR LAILI
# 3     Ana Ayu Arbaatus Sholichah
# 4                Imroatul Azizah
# ..                           ...
# 556  Fajar Dianti Khoeroh Saadah
# 557                   Siti Amina
# 558              Ma'ruf Sya'roni
# 559              Rofiatul Zuhria
# 560                 HENI ROSIDAH
#
#                                                  judul  \
# 0    “PENERAPAN SHARIA MARKETING MIX  DALAM MENINGK...
# 1    Pengaruh Biaya Ijarah, Prosedur Pencairan dan ...
# 2    TINJAUAN EKONOMI ISLAM TERHADAP PENGUPAHAN KAR...
# 3    Pengaruh Pembiayaan Murabahah terhadap Pemberd...
# 4    Analisis Persepsi dan Respon Pedagang Muslim t...
# ..                                                 ...
# 556  Pengaruh Asset Growth, Current Ratio, dan Debt...
# 557  Analisis Tingkat Literasi Zakat Masyarakat di ...
# 558  PENGARUH KUALITAS PRODUK DAN HARGA TERHADAP KE...
# 559  Model pemberdayaan ekonomi masyarakat melalui ...
# 560  ANALISIS MANAJEMEN PENGELOLAAN WAKAF TUNAI PRO...
#
#                                     pembimbing_pertama pembimbing_kedua  \
# 0                     LAILATUL QADARIYAH, S.H.I, M.E.I                -
# 1                      Lailatul Qadariyah, S.HI., M.EI
# 2    Dr. Abdur Rohman, S.Ag.,M.E.I NIP. 19740815200...
# 3                          Dr.Abdur Rohman, S.Ag.,M.EI                -
# 4                      Dony Burhan Noor Hasan L.C.,M.A
# ..                                                 ...              ...
# 556                               Dahruji, S.E., M.E.I
# 557                    Dr. Abdur Rahman, S.Ag., M.E.I.
# 558                           Dzikrulloh, S.EI., M.SEI
# 559                    Dr.Abdur Rahman, S. Ag., M.E.I.
# 560                    DR. ABDUR ROHMAN, S.AG., M.E.I.
#
#                                           abstrak_indo  \
# 0    ABSTRAK\r\nPenelitian ini akan membahas tentan...
# 1    Penelitian yang berjudul pengaruh biaya ijarah...
# 2    Penelitian ini akan membahas tentang tinjauan ...
# 3    Penelitian yang berjudul pengaruh pembiayaan M...
# 4    Lembaga Keuangan Syariah non bank yang keberad...
# ..                                                 ...
# 556  Nilai perusahaan merupakan bagian terpenting y...
# 557  Literasi zakat merupakan pengetahuan, keteramp...
# 558  ABSTRAK\nTujuan penelitian ini adalah untuk me...
# 559  Kedai kopi sampah merupakan salah satu usaha y...
# 560  Penelitian ini dilatar belakangi oleh adanya B...
#
#                                        abstrak_inggris
# 0    ABSTRACT\r\nThis research is going to discuss ...
# 1    The research is entitled the impact of ijarah ...
# 2    This research will discuss the Islamic Economi...
# 3    The study entitled influence Murabahah financi...
# 4    Perception and Response Analysis of the Existe...
# ..                                                 ...
# 556  Company value is the most important part that ...
# 557  Zakat literacy is knowledge, skills and belief...
# 558  ABSTRACT\nThe purpose of this research is to k...
# 559  The junk coffee shop is one of the businesses ...
# 560  This research is motivated by the existence of...
#
# [561 rows x 6 columns]

# %% [markdown]
# ### Hukum Bisnis Syariah

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def HBS():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 84):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/17/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("HBS.csv", index=False)

    return df

# %%
HBS()
# Out:
#                  penulis                                              judul  \
# 0       MUHAMMAD HENDRIK  PENETAPAN UJROH DI PEGADAIAN SYARIAH BANGKALAN...
# 1               nuruddin  tinjauan hukum Islam terhadap penerapan denda ...
# 2           Sumar Rohman  Konversi Gadai Menjadi Nilai Daging Sapi Persp...
# 3               RUMSIYAH  TINJAUAN HUKUM ISLAM TERHADAP TRADISI PENGURAN...
# 4             Adam Malik  PRAKTEK PERMODALAN BERSYARAT MENURUT HUKUM ISL...
# ..                   ...                                                ...
# 409      Faizatun Nazila  TINJAUAN HUKUM ISLAM  TERHADAP BISNIS JASA TRA...
# 410  Dwi Nisa'ul farihah  Tinjauan Sosiologi Hukum Islam Terhadap Prakti...
# 411       Mohammad Zaini  Tinjauan Maslahah Mursalah Tentang Putusan Ver...
# 412              Halimah  ANALISIS INVESTASI SYARIAH DITINJAU DARI AL-MA...
# 413         Imam Farodhi  Tinjauan Mas}lahah Terhadap Penetapan Fatwa No...
#
#                   pembimbing_pertama pembimbing_kedua  \
# 0          H. ACH. MUS'IF, S.HI., MA
# 1                  shofiyun nahidloh
# 2    Shofiyun Nahidloh, S. Ag., M.HI
# 3        SHOFIUN NAHIDLOH,S.Ag.,M.HI
# 4       Shofiyun Nahidloh,S.Ag.,M.HI
# ..                               ...              ...
# 409   Shofiyun Nahidloh, S.Ag.,M.H.I
# 410                 Hamam, Lc., M.sy
# 411  Shofiyun Nahidloh, S.Ag., M.H.I
# 412       Mohammad Hipni, S.HI.,M.HI
# 413       Busro Karim, S.Hum.,M.Pd.I
#
#                                           abstrak_indo  \
# 0
# 1    Transaksi pinjam meminjam buku diperpustakaan ...
# 2    ABSTRAK\r\nGadai ini merupakan bagian dari pra...
# 3    ABSTRAK\r\nTimbangan merupakan jenis pengukura...
# 4    ABSTRAK\r\n\tSkripsi ini adalah hasil peneliti...
# ..                                                 ...
# 409  Perbedaan harga yang diterapkan pemilik jasa t...
# 410  Skripsi yang berjudul tinjauan sosiologi hukum...
# 411  Pengadilan agama sebagai salah satu kekuasaan ...
# 412  Skripsi ini bejudul “Analisis Investasi Syaria...
# 413  Musha>rakah Mutana>qis}ah merupakan sebuah aka...
#
#                                        abstrak_inggris
# 0
# 1    ABSTRACT\r\nThe library book lending and borro...
# 2    ABSTRACT\r\nThe pawn is a part of Muamalah pra...
# 3    ABSTRACT\r\nScales is the tool to gauge someth...
# 4    ABSTRACT\r\n\tThis thesis is the result of a s...
# ..                                                 ...
# 409  The price difference applied by the transporta...
# 410  The thesis entitled the review of Islamic lega...
# 411  The religious court as one of the judicial aut...
# 412  This thesis entitled "An Analysis of Sharia In...
# 413  Musha>rakah Mutana>qis}ah is a financing agree...
#
# [414 rows x 6 columns]

# %% [markdown]
# ## Pendidikan

# %% [markdown]
# ### PGSD

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def pgsd():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 184):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/18/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("pgsd.csv", index=False)

    return df

# %%
pgsd()
# Out:
#                       penulis  \
# 0             Dessy Setyowati
# 1                Holiyah Sari
# 2      Dwi Indah Rahayuingsih
# 3           Fatimatus Zakiyah
# 4              Diska Febriadi
# ..                        ...
# 908  ALDY ADITYA FABIAN YAHYA
# 909         Ratih Permatasari
# 910            Zuliya Safutri
# 911            Lyta Pranawati
# 912             Leni Marlinda
#
#                                                  judul  \
# 0    Pengaruh Penggunaan Media Audio Visual Terhada...
# 1    Strategi Sekolah dalam Upaya Penguatan Karakte...
# 2    Perbandingan Hasil Belajar Cooperative Learnin...
# 3    Kemampuan Berpikir Tingkat Tinggi Siswa Kelas ...
# 4    Hubungan Antara Kemandirian Belajar dengan Has...
# ..                                                 ...
# 908  PENGEMBANGAN MAJALAH BERBASIS GAME MOBILE LEGE...
# 909  PENGEMBANGAN PERANGKAT PEMBELAJARAN MODEL\nPRO...
# 910  Problematika Pembelajaran Daring Siswa Kelas R...
# 911  PENDAMPINGAN ORANG TUA DALAM PROSES BELAJAR AN...
# 912  peran Guru Dalam Menanamkan NIlai-Nilai Kearif...
#
#                       pembimbing_pertama  \
# 0             Drs. Harun Al Rasyid, M.Si
# 1                Mujtahidin, S.Pd., M.Pd
# 2           Eva Ari Wahyuni, S.Pd., M.Si
# 3    Priyono Tri Febrianto, S.Sos., M.Si
# 4            Drs. Harun Al Rasyid, M.Si.
# ..                                   ...
# 908           Fachrur Rozie, S.Pd.,M.Pd.
# 909          Rika Wulandari, S.Pd., M.Pd
# 910                 Mahmud, S.IP., M.Si.
# 911  Priyono Tri Febrianto, S.Sos., M.Si
# 912                  mahmud, S.IP.,M.Si.
#
#                              pembimbing_kedua  \
# 0                Wanda Ramansyah, S.Pd., M.Pd
# 1              Moh. Edy Nurtamam, S.Pd., M.Si
# 2          Muhammad Busyro Karim, S.Ag., M.Si
# 3                  Wahid Khoirul Ikhwan, M.Pd
# 4         Muhammad Busyro Karim, S.Ag., M.Si.
# ..                                        ...
# 908         Bagus Rahmad Wijaya, S.Pd., M.Pd.
# 909            Conny Dian Sumadi ,S.Pd., M.Pd
# 910  Nilamsari Damayanti Fajrin, S.Pd., M.Pd.
# 911      Andika Adinanda Siswoyo, S.Pd., M.Pd
# 912               Agung Setyawan, S.Pd.,M.Pd.
#
#                                           abstrak_indo  \
# 0    Latar belakang penelitian ini adalah penggunaa...
# 1    Penelitian ini bertujuan untuk mengetahui gamb...
# 2    Penelitian “Perbandingan Hasil Belajar Coopera...
# 3    Penelitian ini bertujuan untuk mengetahui kema...
# 4    Penelitian ini bertujuan untuk mengetahui hubu...
# ..                                                 ...
# 908  ABSTRAK\nTujuan  penelitian  pengembangan  ini...
# 909  ABSTRAK\nPerangkat pembelajaran adalah bentuk ...
# 910  Tujuan dalam Penelitian ini adalah mengetahui ...
# 911  Abstrak\n\nTujuan dari penelitian ini yaitu un...
# 912  Abstrak\nPeran guru dalam melestarikan kebuday...
#
#                                        abstrak_inggris
# 0    The background of this study  is the use of me...
# 1    This research is conducted by purposed to find...
# 2    A Study about “Cooperative Learning Result Com...
# 3    The aim of this research is to know the Higher...
# 4    This reserach aims to know the relationship be...
# ..                                                 ...
# 908  ABSTRACT\nThe purpose of this development rese...
# 909  ABSRACT\nLearning tools are a form of teacher ...
# 910  The purpose of this study is to determine the ...
# 911  Abstract\n\nThe purpose of this study is to fi...
# 912  ABSTRACT\nThe role of the teacher in preservin...
#
# [913 rows x 6 columns]

# %% [markdown]
# ### PBSI

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def pbsi():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 74):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/27/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("pbsi.csv", index=False)

    return df

# %%
pbsi()
# Out:
#                        penulis  \
# 0            MAULIDIYA IRAWATI
# 1        Grasia Wahyu Kharisma
# 2                     Tasrifah
# 3                       Nurdin
# 4       Ulul Albabiyatul Husna
# ..                         ...
# 360        Abdur Rochman Wahid
# 361  MOHAMMAD NUR HIDAYATULLAH
# 362             Lia Yuliantina
# 363            Wasiatun Ni’mah
# 364                ISTIBSYAROH
#
#                                                  judul  \
# 0    ANALISIS REGISTER BAHASA MADURA PADA MASYARAKA...
# 1    PENGARUH PENERAPAN  METODE ROLE PLAYING BERBAN...
# 2    MAKNA KONTEKSTUAL PADA JINGLE SLOGAN TELEVISI ...
# 3    INTERFERENSI FONOLOGI BAHASA SUNDA DALAM PENGG...
# 4    KESALAHAN SINTAKSIS PADA KARANGAN NARASI SISWA...
# ..                                                 ...
# 360  Analisis Penerapan Gambar “Augmented Reality” ...
# 361  ANALISIS MODEL PICTURE AND PICTURE MATERI CERI...
# 362  pengaruh motivasi terhadap keterampilan menuli...
# 363  BENTUK DAN FUNGSI PEMAJASAN PERIBAHASA MADURA ...
# 364  ANALISIS PENGGUNAAN KALIMAT ANALITIS,KONTRADIK...
#
#                    pembimbing_pertama                  pembimbing_kedua  \
# 0          Ira Fatmawati, S.S., M.Pd.         Ahmad Jami’ul Amil, M.Pd.
# 1       Khusnul Khotimah, S.S., M.Pd.  Ahmad Jami'ul Amil, S.Pd., M.Pd.
# 2        Khusnul Khotimah. S.S., M.Pd    Ahmad Jami'ul Amil, S.Pd.,M.Pd
# 3       Khusnul Khotimah, S.S., M.Pd.  Ahmad Jami'ul Amil, S.Pd., M.Pd.
# 4       Khusnul Khotimah, S.S., M.Pd.  Ahmad Jami’ul Amil, S.Pd., M.Pd.
# ..                                ...                               ...
# 360          Abdul Rosid, S.Pd., M.Pd   Ahmad Jami'ul Amil, S.Pd., M.Pd
# 361            SULAIMAN, S.Pd., M.Pd.         IKA FEBRIANI, S.S., M.Pd.
# 362  Ahmad Jami'ul Amil, S.Pd., M.Pd.         Abdul Rosid, S.Pd., M.Pd.
# 363           Abdul Rosid, S.Pd, M.Pd          Ika Febriani, S.S, M.Pd.
# 364             SULAIMAN, S.Pd., M.Pd    AHMAD JAMIUL AMIL, S.Pd., M.Pd
#
#                                           abstrak_indo  \
# 0    Abstrak: Penggunaan bahasa Indonesia pada masy...
# 1    Grasia Wahyu Kharisma. 2017. Pengaruh Penerapa...
# 2    Tasrifah. 2017. Makna Kontekstual Pada Jingle ...
# 3    Penelitian ini bertujuan untuk mendeskripsikan...
# 4    Ulul Albabiyatul Husna. 2017. Kesalahan Sintak...
# ..                                                 ...
# 360  Abstrak: Media pembelajaran adalah media yang ...
# 361  Abstrak: Model Picture and Picture merupakan m...
# 362  Penelitian ini merupakan penelitian pendekatan...
# 363  ABSTRAK\nAbstrak: Peribahasa merupakan kalimat...
# 364  ABSTRAK\nAbstrak: Penelitian ini mengkaji bent...
#
#                                        abstrak_inggris
# 0    Abstract: The use of Indonesian reviewed Torju...
# 1    Grasia Wahyu Kharisma. 2017. The Effect of Imp...
# 2    Tasrifah. 2017. The contextual on the jingle s...
# 3    This study has an objective to describe the fo...
# 4    Ulul Albabiyatul Husna. 2017. Syntax Error in ...
# ..                                                 ...
# 360  Abstract: Learning media are media that contai...
# 361  Abstract: The Picture and Picture Model is a l...
# 362  This research is a quantitative approach resea...
# 363  ABSTRACT\n Abstract: Proverbs are sentences or...
# 364  ABSTRACT\nAbstract: This study examines the an...
#
# [365 rows x 6 columns]

# %% [markdown]
# ### Pen.Informatika

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def peninfromatika():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 71):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/28/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("peninfromatika.csv", index=False)

    return df

# %%
peninfromatika()
# Out:
#                           penulis  \
# 0    Nurrohmat Hidayatullah Akbar
# 1                        Cholilah
# 2                 TAUFIKUR RAHMAN
# 3                 Yuliana Wardani
# 4                   Deny Prasetyo
# ..                            ...
# 345                    Nasiruddin
# 346               Samaaul Badi'ah
# 347                       Mahmudy
# 348                Yudhistira PIP
# 349                 Nurul Hasanah
#
#                                                  judul  \
# 0    Pengembangan Game Edukasi 2 Dimensi Untuk Mate...
# 1    Pengembangan Media Pembelajaran Sistem Bilanga...
# 2    PENGARUH MEDIA PEMBELAJARAN E-LEARNING BERBASI...
# 3    PROFIL BERPIKIR KRITIS SISWA KELAS X TKJ DITIN...
# 4    PENGEMBANGAN GAME EDUKASI 3D STRUKTUR ALGORITM...
# ..                                                 ...
# 345  PENGEMBANGAN PERANGKAT PEMBELAJARAN MODEL PEMB...
# 346  Analisis Kesalahan Siswa Berdasarkan Prosedur ...
# 347  Pengembangan Media Pembelajaran Trainer Komput...
# 348  Pengembangan Perangkat Rencana Pembelajaran De...
# 349  PENGEMBANGAN PERANGKAT PEMBELAJARAN KOOPERATIF...
#
#                     pembimbing_pertama                   pembimbing_kedua  \
# 0         Arik Kurniawati, S.Kom. M.T.  Puji Rahayu Ningsih, S.Pd., M.Pd.
# 1         Arik Kurniawati, S.kom., MT.       Wanda Ramansyah, S.Pd., M.Pd
# 2         MEDIKA RISNASARI, S.ST.,M.T.         MUCHAMAD ARIF, S.PD.,M.PD.
# 3       Puji Rahayu Ningsih,S.Pd.,M.Pd       Sigit Dwi Saputo, S.Pd.,M.Pd
# 4      Arik Kurniawati, S. Kom., M. T.   Sigit Dwi Saputro, S.Pd., M. Pd.
# ..                                 ...                                ...
# 345    Puji Rahayu Ningsih, S.Pd.,M.Pd   Muhamad Afif Effindi, S.Kom.,M.T
# 346  Puji Rahayu Ningsih, S.Pd., M.Pd.       Medika Risnasari, S.ST., M.T
# 347       Wanda Ramansyah, S.Pd., M.Pd  Muhamad Afif Effindi, S.Kom., M.T
# 348  Ariesta Kartika Sari, S.Si., M.Pd       Wanda Ramansyah, S.Pd., M.Pd
# 349  Ariesta Kartika Sari, S.Si., M.Pd       Laili Cahyani, S.Kom., M.Kom
#
#                                           abstrak_indo  \
# 0    Materi struktur dasar algoritma pemrograman me...
# 1    Pada Mata Pelajaran Sistem Komputer, siswa har...
# 2    Penelitian ini bertujuan untuk mengetahui peng...
# 3    Abstrak\nPenelitian ini bertujuan untuk menget...
# 4    Mata pelajaran pemrograman dasar merupakan sal...
# ..                                                 ...
# 345  Abstrak\nPenelitian ini bertujuan untuk mengem...
# 346  Siswa mengalami kesulitan dalam materi routing...
# 347  ABSTRAK\n\nPenelitian ini bertujuan untuk menu...
# 348  Penelitian ini di latar belakangi oleh perangk...
# 349  Penelitian ini bertujuan menghasilkan perangka...
#
#                                        abstrak_inggris
# 0    The basic structure of the programming algorit...
# 1    In Computer Systems Subjects, students must co...
# 2    This study aims to determine the effect of lea...
# 3    Abstract\nThis research aims to know the profi...
# 4    Basic subjects that exist in the Department of...
# ..                                                 ...
# 345  Abstrack\nThis study aims to develop learning ...
# 346  Students have difficulty in routing material i...
# 347  ABSTRACT\n\nThis study aims to foster student ...
# 348  This research is motivated by the learning too...
# 349  This study aims to produce a TGT cooperative l...
#
# [350 rows x 6 columns]

# %% [markdown]
# ### Pendidikan IPA

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def penipa():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 85):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/29/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("penipa.csv", index=False)

    return df

# %%
penipa()
# Out:
#                 penulis                                              judul  \
# 0       Anita Enia Urfi  Implementasi Model Pembelajaran Project Based ...
# 1     Rika Dyanita Sari  PENGARUH PEMBELAJARAN IPA MODEL GUIDED DISCOVE...
# 2         Novi Prastiwi  PENGEMBANGAN MAJALAH IPA TERPADU TIPE WEBBED B...
# 3           Aden Toyyib  PENGEMBANGAN LEMBAR KERJA SISWABERORIENTASI \n...
# 4                 ANITA  PENGEMBANGAN PERANGKAT PROBLEM BASED LEARNING ...
# ..                  ...                                                ...
# 412        TRIA MASITAH  Analisis Kemampuan Berpikir Kritis Siswa Mater...
# 413  Indah Sari Mardana  Pengembangan LKS Berbasis Keterampilan Generik...
# 414       Kurroti Uyuni  ANALISIS MISKONSEPSI SISWA PADA MATERI KLASIFI...
# 415       Kurrotul Aini  ANALISIS KEMAMPUAN PEMECAHAN MASALAH SISWA PAD...
# 416             SA'ADAH  ANALISIS RATA-RATA KEMAMPUAN BERPIKIR KRITIS S...
#
#                              pembimbing_pertama  \
# 0                  Mochammad Ahied S.Si., M.Si,
# 1                   Yunin Hidayati, S.Si., M.Si
# 2                   Yunin Hidayati, S.Si., M.Si
# 3                  Yunin Hidayati,  S.Si., M.Si
# 4        Laila Khamsatul Muharrami, S.Si., M.Si
# ..                                          ...
# 412   Ana Yuniasti Retno Wulandari, S.Pd., M.Pd
# 413              Laila khamsatul M, S.Si.,M.Si.
# 414    Laila Khamsatul Muharrami, S. Si., M. Si
# 415                Mochammad Ahied, S.Si., M.Si
# 416  ANA YUNIASTI RETNO WULANDARI, S.PD., M.PD.
#
#                               pembimbing_kedua  \
# 0                    Irsad Rosidi, S.Pd., M.Pd
# 1             Wiwin Puspita Hadi, S.Si., M.Pd.
# 2    Ana Yuniasti Retno Wulandari, S.Pd., M.Pd
# 3                    Irsad Rosidi, S.Pd., M.Pd
# 4    Ana Yuniasti Retno Wulandari, S.Pd., M.Pd
# ..                                         ...
# 412            Wiwin Puspita Hadi, S.Si., M.Pd
# 413                Mochammad Yasir, S.Pd.,M.Pd
# 414                 Irsad Rosidi, S.Pd., M. Pd
# 415               Mochammad Yasir, S.Pd., M.Pd
# 416                AIDA FIKRIYAH, S.PD., M.PD.
#
#                                           abstrak_indo  \
# 0    Penelitian ini bertujuan untuk mengukur tingka...
# 1    Penelitian ini bertujuan untuk mengetahui peng...
# 2    Penelitian dilakukan dengan mengembangkan suat...
# 3    Penelitian ini merupakan penelitian pengembang...
# 4
# ..                                                 ...
# 412  Penelitian ini bertujuan untuk mengidentifikas...
# 413  Penelitian ini bertujuan untuk mengetahui kela...
# 414  Penelitian ini bertujuan untuk mengetahui pers...
# 415  Penelitian ini bertujuan untuk menganalisis ke...
# 416  Penelitian ini bertujuan untuk mengetahui rata...
#
#                                        abstrak_inggris
# 0    The aim of this research is to measure level o...
# 1    The aim in this research was to know the influ...
# 2    This research developed a product, which was i...
# 3    The research aims to know validity of socio sc...
# 4
# ..                                                 ...
# 412  This study was aimed at identifying the percen...
# 413  This study aims to determine the feasibility, ...
# 414  This study aims to determine the percentage of...
# 415  The porpouse of this research is to analyze th...
# 416  This study aims to determine the average resul...
#
# [417 rows x 6 columns]

# %% [markdown]
# ### PGPAUD

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def pgpaud():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 54):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/30/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("pgpaud.csv", index=False)

    return df

# %%
pgpaud()
# Out:
#                               penulis  \
# 0                 Indri Wulan Suryani
# 1                    Endang Ratnasari
# 2    Lischa Dwi Christin Niya Ningrum
# 3                Siti Herlinah Wifroh
# 4            NUR INAYATUR ROHMATILLAH
# ..                                ...
# 258                IFTITAHUR RIZQIYAH
# 259                    Lailatul Izzah
# 260                      Ita Iriyanti
# 261                   Mega Wulan Sari
# 262                Defrika Chamilaini
#
#                                                  judul  \
# 0    Hubungan Antara Aktivitas Fisik Dengan Kedisip...
# 1    Efektivitas Penanaman  Nilai Agama untuk Membe...
# 2    PENGARUH METODE DEMONSTRASI TERHADAP PERILAKU ...
# 3    Pengaruh Strategi Meaningful Instructional Des...
# 4    AGRESIFITAS ANAK USIA 5-6 TAHUN DENGAN POLA AS...
# ..                                                 ...
# 258  PENGASUHAN IBU DENGAN PERAN GANDA PADA ANAK DO...
# 259  Pengembangan Media Buku Dongeng Fabel Untuk Me...
# 260  Hubungan Metode Bercerita Fabel Dengan Sosial-...
# 261  PERAN GURU DALAM PENERAPAN SEKOLAH RAMAH ANAK ...
# 262  Pengaruh Metode Bercakap - cakap terhadap Kema...
#
#                        pembimbing_pertama  \
# 0             Titin Faridatun Nisa', M.Pd
# 1             Titin Faridatun Nisa', M.Pd
# 2     Muhammad Busyro Karim, S.Ag., M.Si.
# 3               Yulias Wulani Fajar, M.Pd
# 4         Siti Fadjryana Fitroh S.Psi.,MA
# ..                                    ...
# 258       Siti Fadjryana Fitroh S.Psi, MA
# 259  Dwi Nurhayati Adhani, S.Psi., M.Psi.
# 260    Dwi Nurhayati Adhani, S.Psi,.M.Psi
# 261   Dwi Nurhayati Adhani, S.Psi., M.Psi
# 262              Busyro Karim,S.Ag, M.Si.
#
#                          pembimbing_kedua  \
# 0               Yulias Wulani Fajar, M.Pd
# 1               Yulias Wulani Fajar, M.Pd
# 2                  Dewi Mayangsari, M.Psi
# 3      Titin Faridatun Nisa', S.Pd., M.Pd
# 4        Titin Faridatun Nisa' S.Pd.,M.Pd
# ..                                    ...
# 258           Dwi Nurhayati Adhani, M.Psi
# 259     Siti Fadjyana Fitroh, S.Psi., MA.
# 260     Muhammad Busyro karim, S.Ag.,M.Si
# 261    Muhammad Busyro Karim, S.Ag., M.Si
# 262  Siti Fadjryana Fitroh, S. Psi., M.A.
#
#                                           abstrak_indo  \
# 0    Pembelajaran pada anak usia dini dilakukan mel...
# 1    Penanaman nilai agama merupakan salah satu pem...
# 2    Kesehatan mempunyai pengaruh terhadap pencapai...
# 3    Tujuan penelitian ini untuk mengetahui pengaru...
# 4    Tujuan penelitian ini adalah untuk mengatahui ...
# ..                                                 ...
# 258  Ibu memiliki peranan penting dalam pengasuhan ...
# 259  ABSTRAK\n\nPenelitian ini bertujuan untuk memb...
# 260  Hubungan Metode Bercerita Fabel Dengan Sosial-...
# 261  ABSTRAK\n Penelitian ini bertujuan untuk mende...
# 262  Tujuan penelitian ini bertujuan untuk mengetah...
#
#                                        abstrak_inggris
# 0    ABSTRAK \n \n Learning in early childhood has ...
# 1    Applying religion value is one of the more dom...
# 2    Health has an influence on the achievement of ...
# 3    The purpose of this study is to reveal the inf...
# 4    The aims of this studyare tounderstand the typ...
# ..                                                 ...
# 258  Mothers have an important role in caring of ch...
# 259  ABSTRACT\nResearch aims to create and develop ...
# 260  The Relation Of The Fabel Story Method With So...
# 261  ABSTRACT\n This study aims to describe the rol...
# 262  The purpose of this study aims to determine th...
#
# [263 rows x 6 columns]

# %% [markdown]
# ### PPG

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def ppg():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 2):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/38/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("ppg.csv", index=False)

    return df

# %%
ppg()
# Out:
# Empty DataFrame
# Columns: [penulis, judul, pembimbing_pertama, pembimbing_kedua, abstrak_indo, abstrak_inggris]
# Index: []

# %% [markdown]
# ## MBKM

# %% [markdown]
# ### MBKM

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def mbkm():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 2):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/99/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("mbkm.csv", index=False)

    return df

# %%
mbkm()
# Out:
# Empty DataFrame
# Columns: [penulis, judul, pembimbing_pertama, pembimbing_kedua, abstrak_indo, abstrak_inggris]
# Index: []

# %% [markdown]
# ## Pascasarjana

# %% [markdown]
# ### Magister Pendidikan Dasar

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def magisterpendidikandasar():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 2):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/39/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("magisterpendidikandasar.csv", index=False)

    return df

# %%
magisterpendidikandasar()
# Out:
# Empty DataFrame
# Columns: [penulis, judul, pembimbing_pertama, pembimbing_kedua, abstrak_indo, abstrak_inggris]
# Index: []

# %% [markdown]
# ### Doktor Pengelolaan Sumber Daya Alam

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def doktorpsda():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak_indo": [],
        "abstrak_inggris": []
    }

    for i in range(1, 2):
        # print(f"📄 Memproses halaman ke-{i}")
        url = "https://pta.trunojoyo.ac.id/c_search/byprod/40/{}".format(i)
        r = requests.get(url)
        request = r.content
        soup = BeautifulSoup(request, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        for jurnal in jurnals:
            response = requests.get(jurnal.select_one('a.gray.button')['href'])
            soup1 = BeautifulSoup(response.content, "html.parser")

            isi = soup1.select_one('div#content_journal')

            judul = isi.select_one('a.title').text.strip()
            penulis = isi.find('span', string=lambda t: t and "Penulis" in t).text.split(' : ')[1].strip()
            pembimbing_pertama = isi.find('span', string=lambda t: t and "Dosen Pembimbing I" in t).text.split(' : ')[1].strip()
            pembimbing_kedua = isi.find('span', string=lambda t: t and "Dosen Pembimbing II" in t).text.split(' :')[1].strip()

            abstrak_paragraf = isi.find_all('p', align="justify")
            abstrak_indo = abstrak_paragraf[0].get_text(strip=True) if len(abstrak_paragraf) >= 1 else ''
            abstrak_inggris = abstrak_paragraf[1].get_text(strip=True) if len(abstrak_paragraf) >= 2 else ''

            data["penulis"].append(penulis)
            data["judul"].append(judul)
            data["pembimbing_pertama"].append(pembimbing_pertama)
            data["pembimbing_kedua"].append(pembimbing_kedua)
            data["abstrak_indo"].append(abstrak_indo)
            data["abstrak_inggris"].append(abstrak_inggris)

        time.sleep(1)  # delay 1 detik tiap halaman

    df = pd.DataFrame(data)
    df.to_csv("doktorpsda.csv", index=False)

    return df

# %%
doktorpsda()
# Out:
# Empty DataFrame
# Columns: [penulis, judul, pembimbing_pertama, pembimbing_kedua, abstrak_indo, abstrak_inggris]
# Index: []
